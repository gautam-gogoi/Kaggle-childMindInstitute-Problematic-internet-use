# %%
import numpy as np 
import pandas as pd 

df_actigraphy= pd.read_pickle('df_actigraphy_features.pkl')
df_features= df = pd.read_pickle('df_featureEngg_v1')

df = df_features.merge(df_actigraphy, on='id', how='left' )
df.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
#    Physical-Weight  ...  enmo_night_75%  enmo_night_max  anglez_night_count  \
# 0             50.8  ...             NaN             NaN                 NaN
# 1             46.0  ...             NaN             NaN                 NaN
# 2             75.6  ...             NaN             NaN                 NaN
# 3             81.6  ...         0.03394        0.344972              3263.0
# 4              NaN  ...             NaN             NaN                 NaN
#
#    anglez_night_mean anglez_night_std  anglez_night_min  anglez_night_25%  \
# 0                NaN              NaN               NaN               NaN
# 1                NaN              NaN               NaN               NaN
# 2                NaN              NaN               NaN               NaN
# 3           8.356508        67.069931        -89.223877        -60.815269
# 4                NaN              NaN               NaN               NaN
#
#    anglez_night_50% anglez_night_75%  anglez_night_max
# 0               NaN              NaN               NaN
# 1               NaN              NaN               NaN
# 2               NaN              NaN               NaN
# 3         -3.679711        80.185307         89.530731
# 4               NaN              NaN               NaN
#
# [5 rows x 259 columns]

# %%
# The following 3 functions have been taken from Ben Hamner's github repository
# https://github.com/benhamner/Metrics
def Cmatrix(rater_a, rater_b, min_rating=None, max_rating=None):
    """
    Returns the confusion matrix between rater's ratings
    """
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(rater_a + rater_b)
    if max_rating is None:
        max_rating = max(rater_a + rater_b)
    num_ratings = int(max_rating - min_rating + 1)
    conf_mat = [[0 for i in range(num_ratings)]
                for j in range(num_ratings)]
    for a, b in zip(rater_a, rater_b):
        conf_mat[a - min_rating][b - min_rating] += 1
    return conf_mat


def histogram(ratings, min_rating=None, max_rating=None):
    """
    Returns the counts of each type of rating that a rater made
    """
    if min_rating is None:
        min_rating = min(ratings)
    if max_rating is None:
        max_rating = max(ratings)
    num_ratings = int(max_rating - min_rating + 1)
    hist_ratings = [0 for x in range(num_ratings)]
    for r in ratings:
        hist_ratings[r - min_rating] += 1
    return hist_ratings


def quadratic_weighted_kappa(y, y_pred):
    """
    Calculates the quadratic weighted kappa
    axquadratic_weighted_kappa calculates the quadratic weighted kappa
    value, which is a measure of inter-rater agreement between two raters
    that provide discrete numeric ratings.  Potential values range from -1
    (representing complete disagreement) to 1 (representing complete
    agreement).  A kappa value of 0 is expected if all agreement is due to
    chance.
    quadratic_weighted_kappa(rater_a, rater_b), where rater_a and rater_b
    each correspond to a list of integer ratings.  These lists must have the
    same length.
    The ratings should be integers, and it is assumed that they contain
    the complete range of possible ratings.
    quadratic_weighted_kappa(X, min_rating, max_rating), where min_rating
    is the minimum possible rating, and max_rating is the maximum possible
    rating
    """
    rater_a = y
    rater_b = y_pred
    min_rating=None
    max_rating=None
    rater_a = np.array(rater_a, dtype=int)
    rater_b = np.array(rater_b, dtype=int)
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(min(rater_a), min(rater_b))
    if max_rating is None:
        max_rating = max(max(rater_a), max(rater_b))
    conf_mat = Cmatrix(rater_a, rater_b,
                                min_rating, max_rating)
    num_ratings = len(conf_mat)
    num_scored_items = float(len(rater_a))

    hist_rater_a = histogram(rater_a, min_rating, max_rating)
    hist_rater_b = histogram(rater_b, min_rating, max_rating)

    numerator = 0.0
    denominator = 0.0

    for i in range(num_ratings):
        for j in range(num_ratings):
            expected_count = (hist_rater_a[i] * hist_rater_b[j]
                              / num_scored_items)
            d = pow(i - j, 2.0) / pow(num_ratings - 1, 2.0)
            numerator += d * conf_mat[i][j] / num_scored_items
            denominator += d * expected_count / num_scored_items

    return (1.0 - numerator / denominator)

# %%
df.info()
df['PCIAT-PCIAT_Total'].describe()
df_sii = df[df['sii']>=0]
print (df_sii.sii.value_counts()) 
print (df_sii.test_train_flag.value_counts())
df_sii['weights'] = np.where(df_sii['sii']==3,5,1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3960 entries, 0 to 3959
# Columns: 259 entries, id to anglez_night_max
# dtypes: float64(244), int64(2), object(13)
# memory usage: 7.9+ MB
# 0.0    1594
# 1.0     730
# 2.0     378
# 3.0      34
# Name: sii, dtype: int64
# Train    2201
# Test      535
# Name: test_train_flag, dtype: int64
# C:\Users\gogoig\AppData\Local\Temp\ipykernel_6628\3730932463.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sii['weights'] = np.where(df_sii['sii']==3,5,1)

# %%
season_cols = [col for col in df_sii.columns if 'Season' in col]
df_sii = df_sii.drop(season_cols, axis=1) 
df_sii.columns

train_labels_sii=df_sii[df_sii['test_train_flag']=='Train']['sii']
test_labels_sii=df_sii[df_sii['test_train_flag']=='Test']['sii']

train_labels_pciat=df_sii[df_sii['test_train_flag']=='Train']['PCIAT-PCIAT_Total']
test_labels_pciat=df_sii[df_sii['test_train_flag']=='Test']['PCIAT-PCIAT_Total']

train_weights=df_sii[df_sii['test_train_flag']=='Train']['weights']
test_weights=df_sii[df_sii['test_train_flag']=='Test']['weights']

pciat_cols = [col for col in df_sii.columns if 'PCIAT-PCIAT' in col]
df_sii = df_sii.drop(pciat_cols, axis=1) 
df_sii = df_sii.drop(['sii'], axis=1)
df_sii.columns
# Out:
# Index(['id', 'Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score',
#        'Physical-BMI', 'Physical-Height', 'Physical-Weight',
#        'Physical-Waist_Circumference', 'Physical-Diastolic_BP',
#        'Physical-HeartRate',
#        ...
#        'enmo_night_max', 'anglez_night_count', 'anglez_night_mean',
#        'anglez_night_std', 'anglez_night_min', 'anglez_night_25%',
#        'anglez_night_50%', 'anglez_night_75%', 'anglez_night_max', 'weights'],
#       dtype='object', length=227)

# %%
print(train_labels_sii.describe())
print(test_labels_sii.describe())

print(train_labels_pciat.describe())
print(test_labels_pciat.describe())
# Out:
# count    2201.000000
# mean        0.584734
# std         0.774728
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: sii, dtype: float64
# count    535.000000
# mean       0.562617
# std        0.756560
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: sii, dtype: float64
# count    2201.000000
# mean       27.954112
# std        20.378246
# min         0.000000
# 25%        12.000000
# 50%        27.000000
# 75%        41.000000
# max        93.000000
# Name: PCIAT-PCIAT_Total, dtype: float64
# count    535.000000
# mean      27.657944
# std       20.193187
# min        0.000000
# 25%       12.000000
# 50%       25.000000
# 75%       41.000000
# max       92.000000
# Name: PCIAT-PCIAT_Total, dtype: float64

# %%
train_features=df_sii[df_sii['test_train_flag']=='Train']
test_features=df_sii[df_sii['test_train_flag']=='Test']

train_features = train_features.drop(['test_train_flag', 'weights'], axis=1)
test_features = test_features.drop(['test_train_flag', 'weights'], axis=1)

# %%
print (test_features.info())
print (train_features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 535 entries, 6 to 3947
# Columns: 225 entries, id to anglez_night_max
# dtypes: float64(222), int64(2), object(1)
# memory usage: 944.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2201 entries, 0 to 3958
# Columns: 225 entries, id to anglez_night_max
# dtypes: float64(222), int64(2), object(1)
# memory usage: 3.8+ MB
# None

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

pipe = Pipeline([
    ("model", HistGradientBoostingRegressor(max_iter=80, max_depth=3))
])

model = GridSearchCV(estimator=pipe,
                 param_grid={
                   'model__max_iter': [10,  30, 50, 70, 90, 110, 130, 150, 200], 
                   'model__max_depth': [1,  3, 5, 7, 9, 11, 13, 15, 20]  
                 },
                 scoring={'kappa': make_scorer(quadratic_weighted_kappa)},
                 refit='kappa',    
                 cv=3)

fit_params= {'model__sample_weight':train_weights}
model.fit(train_features.loc[:,train_features.columns!='id'], train_labels_pciat, **fit_params);


pred= model.predict(train_features.loc[:,train_features.columns!='id'])
plt.scatter(pred, train_labels_pciat)

# %%
pred_test= model.predict(test_features.loc[:,test_features.columns!='id'])
plt.scatter(pred_test, test_labels_pciat)

# %%
def get_sii_from_pciat (pred):
    condlist=[pred<=30, (pred>30)&(pred<50),(pred>=50)&(pred<80),(pred>=80) ]
    choicelist= [0,1,2,3]
    return (np.select(condlist,choicelist))

# %%
pred_train_sii = get_sii_from_pciat(pred)
pred_test_sii = get_sii_from_pciat(pred_test)

# %%
print(quadratic_weighted_kappa(train_labels_sii, pred_train_sii))
print (quadratic_weighted_kappa(test_labels_sii, pred_test_sii))
# Out:
# 0.5991346734374575
# 0.35737893268276677

# %%
import eli5
from eli5.sklearn import PermutationImportance

# Calculate the feature importance
importances = PermutationImportance(model).fit(train_features.loc[:,train_features.columns!='id'], train_labels_pciat)

# Print the feature importance
eli5.show_weights(importances)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0836
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x45
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0734
#
#                     &plusmn; 0.0070
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0634
#
#                     &plusmn; 0.0120
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x49
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0501
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x47
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0264
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x13
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0263
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0182
#
#                     &plusmn; 0.0036
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0174
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x44
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0065
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x163
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x15
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0059
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x62
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0057
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x59
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x21
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0015
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x123
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0046
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
pd.set_option('display.max_rows', 100)
pd.DataFrame(model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.110450      0.013592         0.014236        0.001080
# 1        0.138789      0.003089         0.013934        0.000481
# 2        0.161606      0.004031         0.014995        0.001338
# 3        0.179774      0.001860         0.015234        0.000856
# 4        0.206236      0.006721         0.015133        0.000281
# 5        0.219046      0.004016         0.016360        0.001592
# 6        0.254868      0.007838         0.017358        0.000837
# 7        0.294238      0.010732         0.018868        0.001098
# 8        0.327421      0.005386         0.019189        0.000588
# 9        0.160583      0.000826         0.014066        0.000285
# 10       0.285013      0.006453         0.015531        0.000447
# 11       0.363610      0.001129         0.015522        0.000810
# 12       0.451908      0.002474         0.016400        0.000369
# 13       0.542071      0.015483         0.018548        0.001311
# 14       0.618491      0.003881         0.018029        0.000749
# 15       0.727511      0.033533         0.018900        0.001025
# 16       0.807104      0.016380         0.019048        0.000913
# 17       1.064499      0.032236         0.020788        0.000806
# 18       0.278475      0.003659         0.015845        0.000794
# 19       0.588893      0.045814         0.015060        0.000253
# 20       0.777969      0.032351         0.017220        0.000616
# 21       0.964378      0.028324         0.016414        0.000461
# 22       1.145607      0.041342         0.020054        0.000758
# 23       1.280542      0.036683         0.017817        0.000182
# 24       1.464087      0.029400         0.018435        0.000226
# 25       1.615460      0.050697         0.018643        0.000761
# 26       2.242116      0.089920         0.021567        0.000251
# 27       0.397898      0.005554         0.014985        0.000592
# 28       0.834477      0.013539         0.015888        0.001886
# 29       1.158435      0.050546         0.016751        0.000601
# 30       1.486622      0.053565         0.016575        0.000405
# 31       1.868187      0.029546         0.019320        0.001117
# 32       2.205104      0.115884         0.018809        0.000369
# 33       2.363797      0.046436         0.021909        0.003190
# 34       2.638036      0.153974         0.021110        0.001143
# 35       3.460111      0.077239         0.022247        0.001428
# 36       0.453420      0.019047         0.016411        0.001319
# 37       1.037580      0.035312         0.016309        0.000447
# 38       1.656306      0.014140         0.018038        0.001326
# 39       1.884700      0.052899         0.019518        0.000651
# 40       2.284652      0.052541         0.019919        0.001990
# 41       2.657772      0.026031         0.018912        0.001152
# 42       3.056161      0.033708         0.021290        0.000278
# 43       3.623756      0.151000         0.033395        0.013200
# 44       4.688993      0.144076         0.022586        0.001026
# 45       0.520017      0.056450         0.020371        0.007598
# 46       1.209757      0.087525         0.017457        0.002085
# 47       1.652227      0.040009         0.016933        0.000200
# 48       2.100387      0.029050         0.018211        0.001274
# 49       2.643306      0.009137         0.019626        0.000550
# 50       3.127550      0.020090         0.020028        0.000445
# 51       3.574510      0.184770         0.020395        0.000679
# 52       4.037376      0.065928         0.021502        0.001659
# 53       5.742629      0.268664         0.026227        0.002105
# 54       0.488908      0.006404         0.015983        0.001302
# 55       1.118964      0.015141         0.015180        0.000819
# 56       1.705131      0.054077         0.017860        0.001482
# 57       2.221665      0.061513         0.017430        0.000920
# 58       2.836225      0.079797         0.020794        0.002736
# 59       3.539594      0.117650         0.021317        0.000537
# 60       4.074919      0.071657         0.021898        0.000870
# 61       4.550647      0.088770         0.025094        0.000781
# 62       6.148475      0.356697         0.025180        0.000653
# 63       0.500712      0.010523         0.016473        0.000658
# 64       1.164856      0.050259         0.016790        0.000755
# 65       1.866420      0.064997         0.017616        0.001203
# 66       2.484528      0.157336         0.018945        0.001790
# 67       2.946240      0.037641         0.022499        0.002824
# 68       3.746631      0.191333         0.021217        0.000820
# 69       4.259016      0.071104         0.020776        0.000555
# 70       4.824186      0.054778         0.023754        0.001835
# 71       6.554819      0.252791         0.026958        0.001974
# 72       0.473619      0.006077         0.015370        0.001028
# 73       1.285485      0.181451         0.016388        0.000835
# 74       1.898390      0.035664         0.018545        0.001329
# 75       2.571975      0.030130         0.019656        0.001421
# 76       3.202586      0.004020         0.020231        0.000984
# 77       3.876568      0.100489         0.021085        0.001264
# 78       4.552213      0.180279         0.023316        0.001654
# 79       5.340731      0.114435         0.023228        0.001966
# 80       6.868124      0.068197         0.026285        0.002045
#
#    param_model__max_depth param_model__max_iter  \
# 0                       1                    10
# 1                       1                    30
# 2                       1                    50
# 3                       1                    70
# 4                       1                    90
# 5                       1                   110
# 6                       1                   130
# 7                       1                   150
# 8                       1                   200
# 9                       3                    10
# 10                      3                    30
# 11                      3                    50
# 12                      3                    70
# 13                      3                    90
# 14                      3                   110
# 15                      3                   130
# 16                      3                   150
# 17                      3                   200
# 18                      5                    10
# 19                      5                    30
# 20                      5                    50
# 21                      5                    70
# 22                      5                    90
# 23                      5                   110
# 24                      5                   130
# 25                      5                   150
# 26                      5                   200
# 27                      7                    10
# 28                      7                    30
# 29                      7                    50
# 30                      7                    70
# 31                      7                    90
# 32                      7                   110
# 33                      7                   130
# 34                      7                   150
# 35                      7                   200
# 36                      9                    10
# 37                      9                    30
# 38                      9                    50
# 39                      9                    70
# 40                      9                    90
# 41                      9                   110
# 42                      9                   130
# 43                      9                   150
# 44                      9                   200
# 45                     11                    10
# 46                     11                    30
# 47                     11                    50
# 48                     11                    70
# 49                     11                    90
# 50                     11                   110
# 51                     11                   130
# 52                     11                   150
# 53                     11                   200
# 54                     13                    10
# 55                     13                    30
# 56                     13                    50
# 57                     13                    70
# 58                     13                    90
# 59                     13                   110
# 60                     13                   130
# 61                     13                   150
# 62                     13                   200
# 63                     15                    10
# 64                     15                    30
# 65                     15                    50
# 66                     15                    70
# 67                     15                    90
# 68                     15                   110
# 69                     15                   130
# 70                     15                   150
# 71                     15                   200
# 72                     20                    10
# 73                     20                    30
# 74                     20                    50
# 75                     20                    70
# 76                     20                    90
# 77                     20                   110
# 78                     20                   130
# 79                     20                   150
# 80                     20                   200
#
#                                               params  split0_test_kappa  \
# 0     {'model__max_depth': 1, 'model__max_iter': 10}           0.238017
# 1     {'model__max_depth': 1, 'model__max_iter': 30}           0.374507
# 2     {'model__max_depth': 1, 'model__max_iter': 50}           0.415258
# 3     {'model__max_depth': 1, 'model__max_iter': 70}           0.433592
# 4     {'model__max_depth': 1, 'model__max_iter': 90}           0.442286
# 5    {'model__max_depth': 1, 'model__max_iter': 110}           0.453200
# 6    {'model__max_depth': 1, 'model__max_iter': 130}           0.454684
# 7    {'model__max_depth': 1, 'model__max_iter': 150}           0.455318
# 8    {'model__max_depth': 1, 'model__max_iter': 200}           0.459936
# 9     {'model__max_depth': 3, 'model__max_iter': 10}           0.334134
# 10    {'model__max_depth': 3, 'model__max_iter': 30}           0.449106
# 11    {'model__max_depth': 3, 'model__max_iter': 50}           0.465667
# 12    {'model__max_depth': 3, 'model__max_iter': 70}           0.467101
# 13    {'model__max_depth': 3, 'model__max_iter': 90}           0.470823
# 14   {'model__max_depth': 3, 'model__max_iter': 110}           0.472534
# 15   {'model__max_depth': 3, 'model__max_iter': 130}           0.470748
# 16   {'model__max_depth': 3, 'model__max_iter': 150}           0.467721
# 17   {'model__max_depth': 3, 'model__max_iter': 200}           0.467434
# 18    {'model__max_depth': 5, 'model__max_iter': 10}           0.349553
# 19    {'model__max_depth': 5, 'model__max_iter': 30}           0.441034
# 20    {'model__max_depth': 5, 'model__max_iter': 50}           0.456715
# 21    {'model__max_depth': 5, 'model__max_iter': 70}           0.456832
# 22    {'model__max_depth': 5, 'model__max_iter': 90}           0.457664
# 23   {'model__max_depth': 5, 'model__max_iter': 110}           0.458627
# 24   {'model__max_depth': 5, 'model__max_iter': 130}           0.463357
# 25   {'model__max_depth': 5, 'model__max_iter': 150}           0.461532
# 26   {'model__max_depth': 5, 'model__max_iter': 200}           0.462779
# 27    {'model__max_depth': 7, 'model__max_iter': 10}           0.344027
# 28    {'model__max_depth': 7, 'model__max_iter': 30}           0.443251
# 29    {'model__max_depth': 7, 'model__max_iter': 50}           0.449361
# 30    {'model__max_depth': 7, 'model__max_iter': 70}           0.453490
# 31    {'model__max_depth': 7, 'model__max_iter': 90}           0.450158
# 32   {'model__max_depth': 7, 'model__max_iter': 110}           0.452732
# 33   {'model__max_depth': 7, 'model__max_iter': 130}           0.448648
# 34   {'model__max_depth': 7, 'model__max_iter': 150}           0.448951
# 35   {'model__max_depth': 7, 'model__max_iter': 200}           0.447917
# 36    {'model__max_depth': 9, 'model__max_iter': 10}           0.344774
# 37    {'model__max_depth': 9, 'model__max_iter': 30}           0.434742
# 38    {'model__max_depth': 9, 'model__max_iter': 50}           0.441540
# 39    {'model__max_depth': 9, 'model__max_iter': 70}           0.438509
# 40    {'model__max_depth': 9, 'model__max_iter': 90}           0.439714
# 41   {'model__max_depth': 9, 'model__max_iter': 110}           0.438834
# 42   {'model__max_depth': 9, 'model__max_iter': 130}           0.438394
# 43   {'model__max_depth': 9, 'model__max_iter': 150}           0.436132
# 44   {'model__max_depth': 9, 'model__max_iter': 200}           0.433832
# 45   {'model__max_depth': 11, 'model__max_iter': 10}           0.352961
# 46   {'model__max_depth': 11, 'model__max_iter': 30}           0.438782
# 47   {'model__max_depth': 11, 'model__max_iter': 50}           0.450122
# 48   {'model__max_depth': 11, 'model__max_iter': 70}           0.449094
# 49   {'model__max_depth': 11, 'model__max_iter': 90}           0.447045
# 50  {'model__max_depth': 11, 'model__max_iter': 110}           0.446617
# 51  {'model__max_depth': 11, 'model__max_iter': 130}           0.445402
# 52  {'model__max_depth': 11, 'model__max_iter': 150}           0.443471
# 53  {'model__max_depth': 11, 'model__max_iter': 200}           0.439388
# 54   {'model__max_depth': 13, 'model__max_iter': 10}           0.352961
# 55   {'model__max_depth': 13, 'model__max_iter': 30}           0.442508
# 56   {'model__max_depth': 13, 'model__max_iter': 50}           0.451852
# 57   {'model__max_depth': 13, 'model__max_iter': 70}           0.451618
# 58   {'model__max_depth': 13, 'model__max_iter': 90}           0.447799
# 59  {'model__max_depth': 13, 'model__max_iter': 110}           0.443774
# 60  {'model__max_depth': 13, 'model__max_iter': 130}           0.443214
# 61  {'model__max_depth': 13, 'model__max_iter': 150}           0.441969
# 62  {'model__max_depth': 13, 'model__max_iter': 200}           0.439475
# 63   {'model__max_depth': 15, 'model__max_iter': 10}           0.352961
# 64   {'model__max_depth': 15, 'model__max_iter': 30}           0.444722
# 65   {'model__max_depth': 15, 'model__max_iter': 50}           0.447504
# 66   {'model__max_depth': 15, 'model__max_iter': 70}           0.441257
# 67   {'model__max_depth': 15, 'model__max_iter': 90}           0.440196
# 68  {'model__max_depth': 15, 'model__max_iter': 110}           0.438545
# 69  {'model__max_depth': 15, 'model__max_iter': 130}           0.437146
# 70  {'model__max_depth': 15, 'model__max_iter': 150}           0.433943
# 71  {'model__max_depth': 15, 'model__max_iter': 200}           0.433483
# 72   {'model__max_depth': 20, 'model__max_iter': 10}           0.352961
# 73   {'model__max_depth': 20, 'model__max_iter': 30}           0.442692
# 74   {'model__max_depth': 20, 'model__max_iter': 50}           0.453438
# 75   {'model__max_depth': 20, 'model__max_iter': 70}           0.450045
# 76   {'model__max_depth': 20, 'model__max_iter': 90}           0.442271
# 77  {'model__max_depth': 20, 'model__max_iter': 110}           0.439551
# 78  {'model__max_depth': 20, 'model__max_iter': 130}           0.441239
# 79  {'model__max_depth': 20, 'model__max_iter': 150}           0.439308
# 80  {'model__max_depth': 20, 'model__max_iter': 200}           0.438483
#
#     split1_test_kappa  split2_test_kappa  mean_test_kappa  std_test_kappa  \
# 0            0.256174           0.226945         0.240379        0.012049
# 1            0.404325           0.365106         0.381312        0.016719
# 2            0.459695           0.409160         0.428038        0.022523
# 3            0.478890           0.424027         0.445503        0.023929
# 4            0.487141           0.432295         0.453907        0.023851
# 5            0.490039           0.439078         0.460773        0.021483
# 6            0.493291           0.443428         0.463801        0.021353
# 7            0.494169           0.445415         0.464967        0.021041
# 8            0.499753           0.447988         0.469226        0.022131
# 9            0.364792           0.334186         0.344371        0.014440
# 10           0.490670           0.439859         0.459878        0.022098
# 11           0.498321           0.455681         0.473223        0.018209
# 12           0.498939           0.452159         0.472733        0.019509
# 13           0.499939           0.451148         0.473970        0.020043
# 14           0.495836           0.448802         0.472391        0.019202
# 15           0.492351           0.450084         0.471061        0.017257
# 16           0.491197           0.449071         0.469330        0.017236
# 17           0.486056           0.444569         0.466020        0.016967
# 18           0.387478           0.329209         0.355413        0.024146
# 19           0.488328           0.418852         0.449405        0.028974
# 20           0.501000           0.427310         0.461675        0.030288
# 21           0.502686           0.425637         0.461718        0.031644
# 22           0.501248           0.426150         0.461687        0.030790
# 23           0.499059           0.421999         0.459895        0.031473
# 24           0.496903           0.422099         0.460787        0.030593
# 25           0.495747           0.419187         0.458822        0.031314
# 26           0.492787           0.410915         0.455494        0.033819
# 27           0.395641           0.329008         0.356225        0.028537
# 28           0.482706           0.417591         0.447849        0.026781
# 29           0.484634           0.428794         0.454263        0.023059
# 30           0.487229           0.425883         0.455534        0.025086
# 31           0.486026           0.419275         0.451819        0.027276
# 32           0.484756           0.413136         0.450208        0.029293
# 33           0.482990           0.408711         0.446783        0.030353
# 34           0.480000           0.406811         0.445254        0.029993
# 35           0.477042           0.396370         0.440443        0.033356
# 36           0.392775           0.330530         0.356027        0.026628
# 37           0.499005           0.410119         0.447955        0.037471
# 38           0.495312           0.418333         0.451728        0.032242
# 39           0.492060           0.413821         0.448130        0.032657
# 40           0.488267           0.405153         0.444378        0.034091
# 41           0.483886           0.399719         0.440813        0.034389
# 42           0.478506           0.398369         0.438423        0.032715
# 43           0.479325           0.395522         0.436993        0.034218
# 44           0.472397           0.389898         0.432042        0.033704
# 45           0.394393           0.332772         0.360042        0.025650
# 46           0.485041           0.413043         0.445622        0.029788
# 47           0.489961           0.419486         0.453190        0.028853
# 48           0.487941           0.411481         0.449505        0.031216
# 49           0.487702           0.398112         0.444287        0.036627
# 50           0.484724           0.393030         0.441457        0.037611
# 51           0.483646           0.390381         0.439810        0.038280
# 52           0.482969           0.389237         0.438559        0.038423
# 53           0.479008           0.380696         0.433030        0.040387
# 54           0.394393           0.332772         0.360042        0.025650
# 55           0.485366           0.409470         0.445781        0.031070
# 56           0.489189           0.414857         0.451966        0.030346
# 57           0.485835           0.406916         0.448123        0.032313
# 58           0.488419           0.401559         0.445926        0.035485
# 59           0.486991           0.396315         0.442360        0.037032
# 60           0.483713           0.390287         0.439071        0.038253
# 61           0.484591           0.388456         0.438339        0.039331
# 62           0.480691           0.382834         0.434333        0.040115
# 63           0.394393           0.332772         0.360042        0.025650
# 64           0.492767           0.408520         0.448670        0.034507
# 65           0.489622           0.412642         0.449923        0.031473
# 66           0.488556           0.407651         0.445821        0.033187
# 67           0.490367           0.401707         0.444090        0.036300
# 68           0.485096           0.397049         0.440230        0.035964
# 69           0.485291           0.396743         0.439727        0.036196
# 70           0.481801           0.394031         0.436592        0.035881
# 71           0.483178           0.389406         0.435356        0.038305
# 72           0.394393           0.332772         0.360042        0.025650
# 73           0.495076           0.407482         0.448417        0.035989
# 74           0.489368           0.415799         0.452868        0.030037
# 75           0.488783           0.410654         0.449828        0.031896
# 76           0.482065           0.401410         0.441915        0.032928
# 77           0.477795           0.395914         0.437753        0.033452
# 78           0.474536           0.391051         0.435609        0.034315
# 79           0.473159           0.389504         0.433990        0.034359
# 80           0.467005           0.384925         0.430138        0.034024
#
#     rank_test_kappa
# 0                81
# 1                72
# 2                71
# 3                44
# 4                22
# 5                15
# 6                10
# 7                 9
# 8                 7
# 9                80
# 10               17
# 11                2
# 12                3
# 13                1
# 14                4
# 15                5
# 16                6
# 17                8
# 18               79
# 19               32
# 20               13
# 21               11
# 22               12
# 23               16
# 24               14
# 25               18
# 26               20
# 27               77
# 28               38
# 29               21
# 30               19
# 31               26
# 32               28
# 33               39
# 34               45
# 35               53
# 36               78
# 37               37
# 38               27
# 39               35
# 40               46
# 41               52
# 42               59
# 43               62
# 44               69
# 45               73
# 46               43
# 47               23
# 48               31
# 49               47
# 50               51
# 51               55
# 52               58
# 53               68
# 54               73
# 55               42
# 56               25
# 57               36
# 58               40
# 59               49
# 60               57
# 61               60
# 62               66
# 63               73
# 64               33
# 65               29
# 66               41
# 67               48
# 68               54
# 69               56
# 70               63
# 71               65
# 72               73
# 73               34
# 74               24
# 75               30
# 76               50
# 77               61
# 78               64
# 79               67
# 80               70
