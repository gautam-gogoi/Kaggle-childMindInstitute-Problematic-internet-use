# %% [markdown]
# ***Create first Simple model***\
# Author- Gautam Gogoi\
# Date - 17th Nov \
# Objective- Create first tree based model and understand results

# %%
import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score

# %%
# The following 3 functions have been taken from Ben Hamner's github repository
# https://github.com/benhamner/Metrics
def Cmatrix(rater_a, rater_b, min_rating=None, max_rating=None):
    """
    Returns the confusion matrix between rater's ratings
    """
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(rater_a + rater_b)
    if max_rating is None:
        max_rating = max(rater_a + rater_b)
    num_ratings = int(max_rating - min_rating + 1)
    conf_mat = [[0 for i in range(num_ratings)]
                for j in range(num_ratings)]
    for a, b in zip(rater_a, rater_b):
        conf_mat[a - min_rating][b - min_rating] += 1
    return conf_mat


def histogram(ratings, min_rating=None, max_rating=None):
    """
    Returns the counts of each type of rating that a rater made
    """
    if min_rating is None:
        min_rating = min(ratings)
    if max_rating is None:
        max_rating = max(ratings)
    num_ratings = int(max_rating - min_rating + 1)
    hist_ratings = [0 for x in range(num_ratings)]
    for r in ratings:
        hist_ratings[r - min_rating] += 1
    return hist_ratings


def quadratic_weighted_kappa(y, y_pred):
    """
    Calculates the quadratic weighted kappa
    axquadratic_weighted_kappa calculates the quadratic weighted kappa
    value, which is a measure of inter-rater agreement between two raters
    that provide discrete numeric ratings.  Potential values range from -1
    (representing complete disagreement) to 1 (representing complete
    agreement).  A kappa value of 0 is expected if all agreement is due to
    chance.
    quadratic_weighted_kappa(rater_a, rater_b), where rater_a and rater_b
    each correspond to a list of integer ratings.  These lists must have the
    same length.
    The ratings should be integers, and it is assumed that they contain
    the complete range of possible ratings.
    quadratic_weighted_kappa(X, min_rating, max_rating), where min_rating
    is the minimum possible rating, and max_rating is the maximum possible
    rating
    """
    rater_a = y
    rater_b = y_pred
    min_rating=None
    max_rating=None
    rater_a = np.array(rater_a, dtype=int)
    rater_b = np.array(rater_b, dtype=int)
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(min(rater_a), min(rater_b))
    if max_rating is None:
        max_rating = max(max(rater_a), max(rater_b))
    conf_mat = Cmatrix(rater_a, rater_b,
                                min_rating, max_rating)
    num_ratings = len(conf_mat)
    num_scored_items = float(len(rater_a))

    hist_rater_a = histogram(rater_a, min_rating, max_rating)
    hist_rater_b = histogram(rater_b, min_rating, max_rating)

    numerator = 0.0
    denominator = 0.0

    for i in range(num_ratings):
        for j in range(num_ratings):
            expected_count = (hist_rater_a[i] * hist_rater_b[j]
                              / num_scored_items)
            d = pow(i - j, 2.0) / pow(num_ratings - 1, 2.0)
            numerator += d * conf_mat[i][j] / num_scored_items
            denominator += d * expected_count / num_scored_items

    return (1.0 - numerator / denominator)

# %%
df = pd.read_pickle('df_featureEngg_v1')
df.info()
df['PCIAT-PCIAT_Total'].describe()
df_sii = df[df['sii']>=0]
print (df_sii.sii.value_counts()) 
print (df_sii.test_train_flag.value_counts())
df_sii['weights'] = np.where(df_sii['sii']==3,5,1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 99 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3960 non-null   object
#  1   Basic_Demos-Enroll_Season               3960 non-null   object
#  2   Basic_Demos-Age                         3960 non-null   int64
#  3   Basic_Demos-Sex                         3960 non-null   int64
#  4   CGAS-Season                             2555 non-null   object
#  5   CGAS-CGAS_Score                         2420 non-null   float64
#  6   Physical-Season                         3310 non-null   object
#  7   Physical-BMI                            3022 non-null   float64
#  8   Physical-Height                         3027 non-null   float64
#  9   Physical-Weight                         3076 non-null   float64
#  10  Physical-Waist_Circumference            898 non-null    float64
#  11  Physical-Diastolic_BP                   2954 non-null   float64
#  12  Physical-HeartRate                      2967 non-null   float64
#  13  Physical-Systolic_BP                    2954 non-null   float64
#  14  Fitness_Endurance-Season                1308 non-null   object
#  15  Fitness_Endurance-Max_Stage             743 non-null    float64
#  16  Fitness_Endurance-Time_Mins             740 non-null    float64
#  17  Fitness_Endurance-Time_Sec              740 non-null    float64
#  18  FGC-Season                              3346 non-null   object
#  19  FGC-FGC_CU                              2322 non-null   float64
#  20  FGC-FGC_CU_Zone                         2282 non-null   float64
#  21  FGC-FGC_GSND                            1074 non-null   float64
#  22  FGC-FGC_GSND_Zone                       1062 non-null   float64
#  23  FGC-FGC_GSD                             1074 non-null   float64
#  24  FGC-FGC_GSD_Zone                        1063 non-null   float64
#  25  FGC-FGC_PU                              2310 non-null   float64
#  26  FGC-FGC_PU_Zone                         2271 non-null   float64
#  27  FGC-FGC_SRL                             2305 non-null   float64
#  28  FGC-FGC_SRL_Zone                        2267 non-null   float64
#  29  FGC-FGC_SRR                             2307 non-null   float64
#  30  FGC-FGC_SRR_Zone                        2269 non-null   float64
#  31  FGC-FGC_TL                              2324 non-null   float64
#  32  FGC-FGC_TL_Zone                         2285 non-null   float64
#  33  BIA-Season                              2145 non-null   object
#  34  BIA-BIA_Activity_Level_num              1991 non-null   float64
#  35  BIA-BIA_BMC                             1989 non-null   float64
#  36  BIA-BIA_BMI                             1991 non-null   float64
#  37  BIA-BIA_BMR                             1989 non-null   float64
#  38  BIA-BIA_DEE                             1989 non-null   float64
#  39  BIA-BIA_ECW                             1990 non-null   float64
#  40  BIA-BIA_FFM                             1989 non-null   float64
#  41  BIA-BIA_FFMI                            1991 non-null   float64
#  42  BIA-BIA_FMI                             1991 non-null   float64
#  43  BIA-BIA_Fat                             1956 non-null   float64
#  44  BIA-BIA_Frame_num                       1991 non-null   float64
#  45  BIA-BIA_ICW                             1989 non-null   float64
#  46  BIA-BIA_LDM                             1989 non-null   float64
#  47  BIA-BIA_LST                             1989 non-null   float64
#  48  BIA-BIA_SMM                             1989 non-null   float64
#  49  BIA-BIA_TBW                             1989 non-null   float64
#  50  PAQ_A-Season                            475 non-null    object
#  51  PAQ_A-PAQ_A_Total                       475 non-null    float64
#  52  PAQ_C-Season                            1721 non-null   object
#  53  PAQ_C-PAQ_C_Total                       1721 non-null   float64
#  54  PCIAT-Season                            2736 non-null   object
#  55  PCIAT-PCIAT_01                          2733 non-null   float64
#  56  PCIAT-PCIAT_02                          2734 non-null   float64
#  57  PCIAT-PCIAT_03                          2731 non-null   float64
#  58  PCIAT-PCIAT_04                          2731 non-null   float64
#  59  PCIAT-PCIAT_05                          2729 non-null   float64
#  60  PCIAT-PCIAT_06                          2732 non-null   float64
#  61  PCIAT-PCIAT_07                          2729 non-null   float64
#  62  PCIAT-PCIAT_08                          2730 non-null   float64
#  63  PCIAT-PCIAT_09                          2730 non-null   float64
#  64  PCIAT-PCIAT_10                          2733 non-null   float64
#  65  PCIAT-PCIAT_11                          2734 non-null   float64
#  66  PCIAT-PCIAT_12                          2731 non-null   float64
#  67  PCIAT-PCIAT_13                          2729 non-null   float64
#  68  PCIAT-PCIAT_14                          2732 non-null   float64
#  69  PCIAT-PCIAT_15                          2730 non-null   float64
#  70  PCIAT-PCIAT_16                          2728 non-null   float64
#  71  PCIAT-PCIAT_17                          2725 non-null   float64
#  72  PCIAT-PCIAT_18                          2728 non-null   float64
#  73  PCIAT-PCIAT_19                          2730 non-null   float64
#  74  PCIAT-PCIAT_20                          2733 non-null   float64
#  75  PCIAT-PCIAT_Total                       2736 non-null   float64
#  76  SDS-Season                              2618 non-null   object
#  77  SDS-SDS_Total_Raw                       2609 non-null   float64
#  78  SDS-SDS_Total_T                         2606 non-null   float64
#  79  PreInt_EduHx-Season                     3540 non-null   object
#  80  PreInt_EduHx-computerinternet_hoursday  3301 non-null   float64
#  81  sii                                     3960 non-null   float64
#  82  Physical_BMI_Age                        3022 non-null   float64
#  83  Internet_Hours_Age                      3301 non-null   float64
#  84  Physical_BMI_Internet_Hours             2873 non-null   float64
#  85  BIA2_BFP_BMI                            1991 non-null   float64
#  86  BIA2_FFMI_BFP                           1991 non-null   float64
#  87  BIA2_FMI_BFP                            1991 non-null   float64
#  88  BIA2_LST_TBW                            1991 non-null   float64
#  89  BIA2_BFP_BMR                            1991 non-null   float64
#  90  BIA2_BFP_DEE                            1991 non-null   float64
#  91  BIA2_BMR_Weight                         1972 non-null   float64
#  92  BIA2_DEE_Weight                         1972 non-null   float64
#  93  BIA2_SMM_Height                         1971 non-null   float64
#  94  BIA2_Muscle_to_Fat                      1743 non-null   float64
#  95  BIA2_Hydration_Status                   1972 non-null   float64
#  96  BIA2_ICW_TBW                            1991 non-null   float64
#  97  rand_num                                3960 non-null   float64
#  98  test_train_flag                         3960 non-null   object
# dtypes: float64(84), int64(2), object(13)
# memory usage: 3.0+ MB
# 0.0    1594
# 1.0     730
# 2.0     378
# 3.0      34
# Name: sii, dtype: int64
# Train    2173
# Test      563
# Name: test_train_flag, dtype: int64
# C:\Users\gogoig\AppData\Local\Temp\ipykernel_32732\3956500569.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sii['weights'] = np.where(df_sii['sii']==3,5,1)

# %%
season_cols = [col for col in df_sii.columns if 'Season' in col]
df_sii = df_sii.drop(season_cols, axis=1) 
df_sii.columns

train_labels_sii=df_sii[df_sii['test_train_flag']=='Train']['sii']
test_labels_sii=df_sii[df_sii['test_train_flag']=='Test']['sii']

train_labels_pciat=df_sii[df_sii['test_train_flag']=='Train']['PCIAT-PCIAT_Total']
test_labels_pciat=df_sii[df_sii['test_train_flag']=='Test']['PCIAT-PCIAT_Total']

train_weights=df_sii[df_sii['test_train_flag']=='Train']['weights']
test_weights=df_sii[df_sii['test_train_flag']=='Test']['weights']

pciat_cols = [col for col in df_sii.columns if 'PCIAT-PCIAT' in col]
df_sii = df_sii.drop(pciat_cols, axis=1) 
df_sii = df_sii.drop(['sii'], axis=1)
df_sii.columns
# Out:
# Index(['id', 'Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score',
#        'Physical-BMI', 'Physical-Height', 'Physical-Weight',
#        'Physical-Waist_Circumference', 'Physical-Diastolic_BP',
#        'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Max_Stage', 'Fitness_Endurance-Time_Mins',
#        'Fitness_Endurance-Time_Sec', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone',
#        'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone',
#        'FGC-FGC_PU', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone',
#        'FGC-FGC_SRR', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-PAQ_A_Total', 'PAQ_C-PAQ_C_Total',
#        'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T',
#        'PreInt_EduHx-computerinternet_hoursday', 'Physical_BMI_Age',
#        'Internet_Hours_Age', 'Physical_BMI_Internet_Hours', 'BIA2_BFP_BMI',
#        'BIA2_FFMI_BFP', 'BIA2_FMI_BFP', 'BIA2_LST_TBW', 'BIA2_BFP_BMR',
#        'BIA2_BFP_DEE', 'BIA2_BMR_Weight', 'BIA2_DEE_Weight', 'BIA2_SMM_Height',
#        'BIA2_Muscle_to_Fat', 'BIA2_Hydration_Status', 'BIA2_ICW_TBW',
#        'rand_num', 'test_train_flag', 'weights'],
#       dtype='object')

# %%
print(train_labels_sii.describe())
print(test_labels_sii.describe())

print(train_labels_pciat.describe())
print(test_labels_pciat.describe())
# Out:
# count    2173.000000
# mean        0.585366
# std         0.777034
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: sii, dtype: float64
# count    563.000000
# mean       0.561279
# std        0.748231
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: sii, dtype: float64
# count    2173.000000
# mean       28.104464
# std        20.501418
# min         0.000000
# 25%        12.000000
# 50%        27.000000
# 75%        41.000000
# max        92.000000
# Name: PCIAT-PCIAT_Total, dtype: float64
# count    563.000000
# mean      27.092362
# std       19.695963
# min        0.000000
# 25%       11.000000
# 50%       26.000000
# 75%       40.000000
# max       93.000000
# Name: PCIAT-PCIAT_Total, dtype: float64

# %%
train_features=df_sii[df_sii['test_train_flag']=='Train']
test_features=df_sii[df_sii['test_train_flag']=='Test']

train_features = train_features.drop(['test_train_flag', 'weights'], axis=1)
test_features = test_features.drop(['test_train_flag', 'weights'], axis=1)

# %%
print (test_features.info())
print (train_features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 0 to 3955
# Data columns (total 65 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      563 non-null    object
#  1   Basic_Demos-Age                         563 non-null    int64
#  2   Basic_Demos-Sex                         563 non-null    int64
#  3   CGAS-CGAS_Score                         478 non-null    float64
#  4   Physical-BMI                            517 non-null    float64
#  5   Physical-Height                         518 non-null    float64
#  6   Physical-Weight                         525 non-null    float64
#  7   Physical-Waist_Circumference            106 non-null    float64
#  8   Physical-Diastolic_BP                   506 non-null    float64
#  9   Physical-HeartRate                      507 non-null    float64
#  10  Physical-Systolic_BP                    506 non-null    float64
#  11  Fitness_Endurance-Max_Stage             147 non-null    float64
#  12  Fitness_Endurance-Time_Mins             145 non-null    float64
#  13  Fitness_Endurance-Time_Sec              145 non-null    float64
#  14  FGC-FGC_CU                              384 non-null    float64
#  15  FGC-FGC_CU_Zone                         372 non-null    float64
#  16  FGC-FGC_GSND                            157 non-null    float64
#  17  FGC-FGC_GSND_Zone                       157 non-null    float64
#  18  FGC-FGC_GSD                             157 non-null    float64
#  19  FGC-FGC_GSD_Zone                        157 non-null    float64
#  20  FGC-FGC_PU                              381 non-null    float64
#  21  FGC-FGC_PU_Zone                         369 non-null    float64
#  22  FGC-FGC_SRL                             383 non-null    float64
#  23  FGC-FGC_SRL_Zone                        371 non-null    float64
#  24  FGC-FGC_SRR                             383 non-null    float64
#  25  FGC-FGC_SRR_Zone                        371 non-null    float64
#  26  FGC-FGC_TL                              385 non-null    float64
#  27  FGC-FGC_TL_Zone                         373 non-null    float64
#  28  BIA-BIA_Activity_Level_num              376 non-null    float64
#  29  BIA-BIA_BMC                             376 non-null    float64
#  30  BIA-BIA_BMI                             376 non-null    float64
#  31  BIA-BIA_BMR                             376 non-null    float64
#  32  BIA-BIA_DEE                             376 non-null    float64
#  33  BIA-BIA_ECW                             376 non-null    float64
#  34  BIA-BIA_FFM                             376 non-null    float64
#  35  BIA-BIA_FFMI                            376 non-null    float64
#  36  BIA-BIA_FMI                             376 non-null    float64
#  37  BIA-BIA_Fat                             369 non-null    float64
#  38  BIA-BIA_Frame_num                       376 non-null    float64
#  39  BIA-BIA_ICW                             376 non-null    float64
#  40  BIA-BIA_LDM                             376 non-null    float64
#  41  BIA-BIA_LST                             376 non-null    float64
#  42  BIA-BIA_SMM                             376 non-null    float64
#  43  BIA-BIA_TBW                             376 non-null    float64
#  44  PAQ_A-PAQ_A_Total                       69 non-null     float64
#  45  PAQ_C-PAQ_C_Total                       282 non-null    float64
#  46  SDS-SDS_Total_Raw                       507 non-null    float64
#  47  SDS-SDS_Total_T                         507 non-null    float64
#  48  PreInt_EduHx-computerinternet_hoursday  542 non-null    float64
#  49  Physical_BMI_Age                        517 non-null    float64
#  50  Internet_Hours_Age                      542 non-null    float64
#  51  Physical_BMI_Internet_Hours             504 non-null    float64
#  52  BIA2_BFP_BMI                            376 non-null    float64
#  53  BIA2_FFMI_BFP                           376 non-null    float64
#  54  BIA2_FMI_BFP                            376 non-null    float64
#  55  BIA2_LST_TBW                            376 non-null    float64
#  56  BIA2_BFP_BMR                            376 non-null    float64
#  57  BIA2_BFP_DEE                            376 non-null    float64
#  58  BIA2_BMR_Weight                         374 non-null    float64
#  59  BIA2_DEE_Weight                         374 non-null    float64
#  60  BIA2_SMM_Height                         374 non-null    float64
#  61  BIA2_Muscle_to_Fat                      327 non-null    float64
#  62  BIA2_Hydration_Status                   374 non-null    float64
#  63  BIA2_ICW_TBW                            376 non-null    float64
#  64  rand_num                                563 non-null    float64
# dtypes: float64(62), int64(2), object(1)
# memory usage: 290.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2173 entries, 3 to 3958
# Data columns (total 65 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      2173 non-null   object
#  1   Basic_Demos-Age                         2173 non-null   int64
#  2   Basic_Demos-Sex                         2173 non-null   int64
#  3   CGAS-CGAS_Score                         1864 non-null   float64
#  4   Physical-BMI                            2010 non-null   float64
#  5   Physical-Height                         2012 non-null   float64
#  6   Physical-Weight                         2047 non-null   float64
#  7   Physical-Waist_Circumference            377 non-null    float64
#  8   Physical-Diastolic_BP                   1972 non-null   float64
#  9   Physical-HeartRate                      1979 non-null   float64
#  10  Physical-Systolic_BP                    1972 non-null   float64
#  11  Fitness_Endurance-Max_Stage             584 non-null    float64
#  12  Fitness_Endurance-Time_Mins             583 non-null    float64
#  13  Fitness_Endurance-Time_Sec              583 non-null    float64
#  14  FGC-FGC_CU                              1535 non-null   float64
#  15  FGC-FGC_CU_Zone                         1512 non-null   float64
#  16  FGC-FGC_GSND                            715 non-null    float64
#  17  FGC-FGC_GSND_Zone                       707 non-null    float64
#  18  FGC-FGC_GSD                             714 non-null    float64
#  19  FGC-FGC_GSD_Zone                        707 non-null    float64
#  20  FGC-FGC_PU                              1528 non-null   float64
#  21  FGC-FGC_PU_Zone                         1506 non-null   float64
#  22  FGC-FGC_SRL                             1528 non-null   float64
#  23  FGC-FGC_SRL_Zone                        1506 non-null   float64
#  24  FGC-FGC_SRR                             1530 non-null   float64
#  25  FGC-FGC_SRR_Zone                        1508 non-null   float64
#  26  FGC-FGC_TL                              1534 non-null   float64
#  27  FGC-FGC_TL_Zone                         1512 non-null   float64
#  28  BIA-BIA_Activity_Level_num              1437 non-null   float64
#  29  BIA-BIA_BMC                             1435 non-null   float64
#  30  BIA-BIA_BMI                             1437 non-null   float64
#  31  BIA-BIA_BMR                             1435 non-null   float64
#  32  BIA-BIA_DEE                             1435 non-null   float64
#  33  BIA-BIA_ECW                             1436 non-null   float64
#  34  BIA-BIA_FFM                             1435 non-null   float64
#  35  BIA-BIA_FFMI                            1437 non-null   float64
#  36  BIA-BIA_FMI                             1437 non-null   float64
#  37  BIA-BIA_Fat                             1413 non-null   float64
#  38  BIA-BIA_Frame_num                       1437 non-null   float64
#  39  BIA-BIA_ICW                             1435 non-null   float64
#  40  BIA-BIA_LDM                             1435 non-null   float64
#  41  BIA-BIA_LST                             1435 non-null   float64
#  42  BIA-BIA_SMM                             1435 non-null   float64
#  43  BIA-BIA_TBW                             1435 non-null   float64
#  44  PAQ_A-PAQ_A_Total                       294 non-null    float64
#  45  PAQ_C-PAQ_C_Total                       1158 non-null   float64
#  46  SDS-SDS_Total_Raw                       2020 non-null   float64
#  47  SDS-SDS_Total_T                         2018 non-null   float64
#  48  PreInt_EduHx-computerinternet_hoursday  2112 non-null   float64
#  49  Physical_BMI_Age                        2010 non-null   float64
#  50  Internet_Hours_Age                      2112 non-null   float64
#  51  Physical_BMI_Internet_Hours             1962 non-null   float64
#  52  BIA2_BFP_BMI                            1437 non-null   float64
#  53  BIA2_FFMI_BFP                           1437 non-null   float64
#  54  BIA2_FMI_BFP                            1437 non-null   float64
#  55  BIA2_LST_TBW                            1437 non-null   float64
#  56  BIA2_BFP_BMR                            1437 non-null   float64
#  57  BIA2_BFP_DEE                            1437 non-null   float64
#  58  BIA2_BMR_Weight                         1433 non-null   float64
#  59  BIA2_DEE_Weight                         1433 non-null   float64
#  60  BIA2_SMM_Height                         1433 non-null   float64
#  61  BIA2_Muscle_to_Fat                      1271 non-null   float64
#  62  BIA2_Hydration_Status                   1433 non-null   float64
#  63  BIA2_ICW_TBW                            1437 non-null   float64
#  64  rand_num                                2173 non-null   float64
# dtypes: float64(62), int64(2), object(1)
# memory usage: 1.1+ MB
# None

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

pipe = Pipeline([
    ("model", HistGradientBoostingRegressor(max_iter=80, max_depth=3))
])

model = GridSearchCV(estimator=pipe,
                 param_grid={
                   'model__max_iter': [10,  30, 50, 70, 90, 110, 130, 150, 200], 
                   'model__max_depth': [1,  3, 5, 7, 9, 11, 13, 15, 20]  
                 },
                 scoring={'kappa': make_scorer(quadratic_weighted_kappa)},
                 refit='kappa',    
                 cv=3)

fit_params= {'model__sample_weight':train_weights}
model.fit(train_features, train_labels_sii, **fit_params);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32732\1848962681.py in <module>
#      23
#      24 pred= model.predict(train_features)
# ---> 25 plt.scatter(pred, train_labels)
#      26 quadratic_weighted_kappa(train_labels_sii, pred)
#
# NameError: name 'train_labels' is not defined

# %%
pred= model.predict(train_features)
plt.scatter(pred, train_labels_sii)
quadratic_weighted_kappa(train_labels_sii, pred)
# Out:
# 0.32205038420387133

# %%
pred_test= model.predict(test_features)
plt.scatter(pred_test, test_labels_sii)
quadratic_weighted_kappa(test_labels_sii, pred_test)
# Out:
# 0.25945825437520875

# %%
pd.set_option('display.max_rows', 100)
pd.DataFrame(model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.030188      0.001139         0.003225    2.573097e-04
# 1        0.044130      0.001248         0.003200    2.821029e-04
# 2        0.055046      0.001921         0.003792    2.412975e-04
# 3        0.066427      0.000762         0.004046    3.748879e-05
# 4        0.076757      0.000985         0.004404    2.231071e-04
# 5        0.088320      0.001452         0.004961    5.692643e-05
# 6        0.103336      0.001292         0.005243    5.824452e-04
# 7        0.116636      0.002311         0.006097    8.274020e-04
# 8        0.147495      0.004056         0.053998    6.514109e-02
# 9        0.046625      0.004424         0.003000    1.946680e-07
# 10       0.083517      0.001834         0.003333    4.720457e-04
# 11       0.118701      0.004008         0.003836    2.332689e-04
# 12       0.146573      0.001683         0.004400    5.654422e-04
# 13       0.177780      0.002316         0.005114    4.228289e-04
# 14       0.213761      0.003177         0.005936    2.360065e-04
# 15       0.251621      0.001360         0.005965    3.622730e-04
# 16       0.293497      0.009205         0.006908    1.324535e-04
# 17       0.387273      0.009982         0.007693    4.370347e-04
# 18       0.083041      0.001558         0.003333    4.696285e-04
# 19       0.173989      0.002993         0.004394    8.093725e-04
# 20       0.248004      0.004083         0.004845    4.897069e-04
# 21       0.310036      0.004190         0.005172    2.353771e-04
# 22       0.375833      0.010083         0.005581    3.726439e-04
# 23       0.452552      0.015697         0.006548    4.137287e-04
# 24       0.510842      0.005023         0.006398    7.569663e-04
# 25       0.577076      0.002134         0.007598    3.451007e-04
# 26       0.758367      0.023541         0.009683    1.004821e-05
# 27       0.116039      0.005351         0.003193    2.712010e-04
# 28       0.255640      0.003764         0.004041    5.868424e-05
# 29       0.362666      0.001819         0.004570    4.116272e-04
# 30       0.465069      0.004493         0.005993    5.425564e-04
# 31       0.576602      0.016781         0.006215    5.751579e-04
# 32       0.663090      0.016464         0.006557    4.159438e-04
# 33       0.781473      0.002788         0.008278    6.434476e-04
# 34       0.993732      0.056363         0.010221    2.148401e-03
# 35       1.148804      0.014604         0.009948    6.277395e-04
# 36       0.122647      0.002864         0.003551    3.246782e-04
# 37       0.291380      0.002557         0.004066    9.277931e-05
# 38       0.441283      0.013769         0.004625    2.772851e-04
# 39       0.556101      0.006296         0.005579    3.655872e-04
# 40       0.694420      0.016973         0.006004    8.135191e-04
# 41       0.813619      0.006704         0.006668    4.714828e-04
# 42       1.044925      0.103888         0.007697    9.220899e-04
# 43       1.102240      0.019089         0.008683    4.529863e-04
# 44       1.579411      0.085583         0.020418    1.359557e-02
# 45       0.129014      0.008395         0.004279    2.990428e-04
# 46       0.346687      0.017698         0.005184    2.592875e-04
# 47       0.524260      0.038423         0.005606    4.691493e-04
# 48       0.628490      0.009682         0.005637    4.825332e-04
# 49       0.900836      0.112031         0.008421    1.149412e-03
# 50       1.064471      0.068710         0.008656    6.868665e-04
# 51       1.327849      0.065268         0.010260    1.254794e-03
# 52       1.230571      0.042140         0.011181    2.733142e-03
# 53       1.749069      0.060621         0.011867    1.445604e-03
# 54       0.133239      0.002529         0.003899    4.093425e-04
# 55       1.055471      0.761203         0.005636    1.061447e-04
# 56       0.825863      0.144212         0.007655    1.665953e-03
# 57       0.774632      0.019243         0.005909    1.616760e-04
# 58       1.042030      0.109958         0.007795    7.430078e-04
# 59       1.122997      0.124347         0.007753    1.111500e-04
# 60       1.331558      0.022726         0.009433    4.108547e-04
# 61       1.396429      0.011316         0.009538    9.544937e-04
# 62       1.784152      0.034162         0.011004    1.414531e-04
# 63       0.138013      0.005727         0.003928    2.610741e-04
# 64       0.318430      0.010481         0.004066    4.633683e-05
# 65       0.600890      0.037057         0.005162    1.393578e-04
# 66       0.743743      0.029573         0.006376    7.250344e-04
# 67       1.020802      0.014595         0.009090    1.303895e-03
# 68       1.092526      0.032251         0.007173    6.092386e-04
# 69       1.357167      0.066534         0.008922    3.002492e-04
# 70       1.503063      0.059804         0.009867    6.530141e-04
# 71       1.819686      0.013409         0.010594    4.291087e-04
# 72       0.121786      0.002917         0.003745    1.907320e-04
# 73       0.310386      0.001612         0.004408    2.190197e-04
# 74       0.502274      0.004501         0.004588    4.634603e-04
# 75       0.744482      0.023693         0.006649    4.720178e-04
# 76       0.876794      0.007259         0.006435    4.889795e-04
# 77       1.069889      0.032243         0.007228    3.205408e-04
# 78       1.355023      0.059323         0.008961    1.815933e-03
# 79       1.550855      0.053567         0.009652    4.604037e-04
# 80       1.911592      0.023979         0.011230    6.849684e-04
#
#    param_model__max_depth param_model__max_iter  \
# 0                       1                    10
# 1                       1                    30
# 2                       1                    50
# 3                       1                    70
# 4                       1                    90
# 5                       1                   110
# 6                       1                   130
# 7                       1                   150
# 8                       1                   200
# 9                       3                    10
# 10                      3                    30
# 11                      3                    50
# 12                      3                    70
# 13                      3                    90
# 14                      3                   110
# 15                      3                   130
# 16                      3                   150
# 17                      3                   200
# 18                      5                    10
# 19                      5                    30
# 20                      5                    50
# 21                      5                    70
# 22                      5                    90
# 23                      5                   110
# 24                      5                   130
# 25                      5                   150
# 26                      5                   200
# 27                      7                    10
# 28                      7                    30
# 29                      7                    50
# 30                      7                    70
# 31                      7                    90
# 32                      7                   110
# 33                      7                   130
# 34                      7                   150
# 35                      7                   200
# 36                      9                    10
# 37                      9                    30
# 38                      9                    50
# 39                      9                    70
# 40                      9                    90
# 41                      9                   110
# 42                      9                   130
# 43                      9                   150
# 44                      9                   200
# 45                     11                    10
# 46                     11                    30
# 47                     11                    50
# 48                     11                    70
# 49                     11                    90
# 50                     11                   110
# 51                     11                   130
# 52                     11                   150
# 53                     11                   200
# 54                     13                    10
# 55                     13                    30
# 56                     13                    50
# 57                     13                    70
# 58                     13                    90
# 59                     13                   110
# 60                     13                   130
# 61                     13                   150
# 62                     13                   200
# 63                     15                    10
# 64                     15                    30
# 65                     15                    50
# 66                     15                    70
# 67                     15                    90
# 68                     15                   110
# 69                     15                   130
# 70                     15                   150
# 71                     15                   200
# 72                     20                    10
# 73                     20                    30
# 74                     20                    50
# 75                     20                    70
# 76                     20                    90
# 77                     20                   110
# 78                     20                   130
# 79                     20                   150
# 80                     20                   200
#
#                                               params  split0_test_kappa  \
# 0     {'model__max_depth': 1, 'model__max_iter': 10}           0.147468
# 1     {'model__max_depth': 1, 'model__max_iter': 30}           0.216512
# 2     {'model__max_depth': 1, 'model__max_iter': 50}           0.257041
# 3     {'model__max_depth': 1, 'model__max_iter': 70}           0.252531
# 4     {'model__max_depth': 1, 'model__max_iter': 90}           0.259583
# 5    {'model__max_depth': 1, 'model__max_iter': 110}           0.257041
# 6    {'model__max_depth': 1, 'model__max_iter': 130}           0.245941
# 7    {'model__max_depth': 1, 'model__max_iter': 150}           0.243722
# 8    {'model__max_depth': 1, 'model__max_iter': 200}           0.248553
# 9     {'model__max_depth': 3, 'model__max_iter': 10}           0.202201
# 10    {'model__max_depth': 3, 'model__max_iter': 30}           0.244560
# 11    {'model__max_depth': 3, 'model__max_iter': 50}           0.233711
# 12    {'model__max_depth': 3, 'model__max_iter': 70}           0.231291
# 13    {'model__max_depth': 3, 'model__max_iter': 90}           0.231954
# 14   {'model__max_depth': 3, 'model__max_iter': 110}           0.236347
# 15   {'model__max_depth': 3, 'model__max_iter': 130}           0.231891
# 16   {'model__max_depth': 3, 'model__max_iter': 150}           0.238715
# 17   {'model__max_depth': 3, 'model__max_iter': 200}           0.241036
# 18    {'model__max_depth': 5, 'model__max_iter': 10}           0.168847
# 19    {'model__max_depth': 5, 'model__max_iter': 30}           0.211520
# 20    {'model__max_depth': 5, 'model__max_iter': 50}           0.218752
# 21    {'model__max_depth': 5, 'model__max_iter': 70}           0.230020
# 22    {'model__max_depth': 5, 'model__max_iter': 90}           0.224224
# 23   {'model__max_depth': 5, 'model__max_iter': 110}           0.224530
# 24   {'model__max_depth': 5, 'model__max_iter': 130}           0.214282
# 25   {'model__max_depth': 5, 'model__max_iter': 150}           0.205801
# 26   {'model__max_depth': 5, 'model__max_iter': 200}           0.206792
# 27    {'model__max_depth': 7, 'model__max_iter': 10}           0.166338
# 28    {'model__max_depth': 7, 'model__max_iter': 30}           0.224903
# 29    {'model__max_depth': 7, 'model__max_iter': 50}           0.243469
# 30    {'model__max_depth': 7, 'model__max_iter': 70}           0.236256
# 31    {'model__max_depth': 7, 'model__max_iter': 90}           0.220465
# 32   {'model__max_depth': 7, 'model__max_iter': 110}           0.224582
# 33   {'model__max_depth': 7, 'model__max_iter': 130}           0.229369
# 34   {'model__max_depth': 7, 'model__max_iter': 150}           0.227998
# 35   {'model__max_depth': 7, 'model__max_iter': 200}           0.245184
# 36    {'model__max_depth': 9, 'model__max_iter': 10}           0.163823
# 37    {'model__max_depth': 9, 'model__max_iter': 30}           0.218358
# 38    {'model__max_depth': 9, 'model__max_iter': 50}           0.235450
# 39    {'model__max_depth': 9, 'model__max_iter': 70}           0.223777
# 40    {'model__max_depth': 9, 'model__max_iter': 90}           0.216953
# 41   {'model__max_depth': 9, 'model__max_iter': 110}           0.220390
# 42   {'model__max_depth': 9, 'model__max_iter': 130}           0.231001
# 43   {'model__max_depth': 9, 'model__max_iter': 150}           0.230651
# 44   {'model__max_depth': 9, 'model__max_iter': 200}           0.230967
# 45   {'model__max_depth': 11, 'model__max_iter': 10}           0.165188
# 46   {'model__max_depth': 11, 'model__max_iter': 30}           0.235589
# 47   {'model__max_depth': 11, 'model__max_iter': 50}           0.230037
# 48   {'model__max_depth': 11, 'model__max_iter': 70}           0.240990
# 49   {'model__max_depth': 11, 'model__max_iter': 90}           0.222774
# 50  {'model__max_depth': 11, 'model__max_iter': 110}           0.227566
# 51  {'model__max_depth': 11, 'model__max_iter': 130}           0.230310
# 52  {'model__max_depth': 11, 'model__max_iter': 150}           0.232706
# 53  {'model__max_depth': 11, 'model__max_iter': 200}           0.237820
# 54   {'model__max_depth': 13, 'model__max_iter': 10}           0.165188
# 55   {'model__max_depth': 13, 'model__max_iter': 30}           0.219704
# 56   {'model__max_depth': 13, 'model__max_iter': 50}           0.241950
# 57   {'model__max_depth': 13, 'model__max_iter': 70}           0.230266
# 58   {'model__max_depth': 13, 'model__max_iter': 90}           0.233007
# 59  {'model__max_depth': 13, 'model__max_iter': 110}           0.231285
# 60  {'model__max_depth': 13, 'model__max_iter': 130}           0.224390
# 61  {'model__max_depth': 13, 'model__max_iter': 150}           0.229556
# 62  {'model__max_depth': 13, 'model__max_iter': 200}           0.230572
# 63   {'model__max_depth': 15, 'model__max_iter': 10}           0.165188
# 64   {'model__max_depth': 15, 'model__max_iter': 30}           0.210006
# 65   {'model__max_depth': 15, 'model__max_iter': 50}           0.222085
# 66   {'model__max_depth': 15, 'model__max_iter': 70}           0.210433
# 67   {'model__max_depth': 15, 'model__max_iter': 90}           0.211079
# 68  {'model__max_depth': 15, 'model__max_iter': 110}           0.205894
# 69  {'model__max_depth': 15, 'model__max_iter': 130}           0.207623
# 70  {'model__max_depth': 15, 'model__max_iter': 150}           0.194273
# 71  {'model__max_depth': 15, 'model__max_iter': 200}           0.205989
# 72   {'model__max_depth': 20, 'model__max_iter': 10}           0.165188
# 73   {'model__max_depth': 20, 'model__max_iter': 30}           0.214491
# 74   {'model__max_depth': 20, 'model__max_iter': 50}           0.220716
# 75   {'model__max_depth': 20, 'model__max_iter': 70}           0.223099
# 76   {'model__max_depth': 20, 'model__max_iter': 90}           0.241258
# 77  {'model__max_depth': 20, 'model__max_iter': 110}           0.246484
# 78  {'model__max_depth': 20, 'model__max_iter': 130}           0.242411
# 79  {'model__max_depth': 20, 'model__max_iter': 150}           0.251478
# 80  {'model__max_depth': 20, 'model__max_iter': 200}           0.250447
#
#     split1_test_kappa  split2_test_kappa  mean_test_kappa  std_test_kappa  \
# 0            0.195883           0.176993         0.173448        0.019924
# 1            0.235209           0.260282         0.237334        0.017932
# 2            0.259309           0.285632         0.267327        0.012976
# 3            0.265606           0.289567         0.269235        0.015336
# 4            0.265620           0.291289         0.272164        0.013746
# 5            0.286122           0.296459         0.279874        0.016688
# 6            0.281959           0.280327         0.269409        0.016608
# 7            0.294828           0.295697         0.278082        0.024299
# 8            0.289868           0.295315         0.277912        0.020878
# 9            0.166749           0.222633         0.197194        0.023087
# 10           0.253503           0.257583         0.251882        0.005439
# 11           0.275751           0.263699         0.257721        0.017676
# 12           0.279138           0.270726         0.260385        0.020857
# 13           0.284551           0.256603         0.257702        0.021486
# 14           0.275785           0.249596         0.253909        0.016387
# 15           0.289969           0.248145         0.256668        0.024464
# 16           0.280396           0.249527         0.256213        0.017661
# 17           0.272028           0.236871         0.249978        0.015684
# 18           0.175017           0.190773         0.178213        0.009232
# 19           0.257900           0.264012         0.244477        0.023438
# 20           0.276282           0.245024         0.246686        0.023516
# 21           0.282596           0.249142         0.253919        0.021728
# 22           0.278094           0.247583         0.249967        0.022057
# 23           0.281786           0.226710         0.244342        0.026492
# 24           0.279788           0.222026         0.238698        0.029226
# 25           0.278611           0.223028         0.235813        0.031069
# 26           0.260061           0.216063         0.227639        0.023237
# 27           0.177072           0.196600         0.180003        0.012527
# 28           0.240698           0.254403         0.240002        0.012053
# 29           0.240701           0.250375         0.244848        0.004068
# 30           0.251042           0.253626         0.246975        0.007652
# 31           0.257698           0.252391         0.243518        0.016444
# 32           0.248999           0.244068         0.239216        0.010542
# 33           0.238380           0.249010         0.238920        0.008028
# 34           0.250115           0.235912         0.238008        0.009150
# 35           0.251649           0.227311         0.241381        0.010293
# 36           0.187958           0.191158         0.180980        0.012202
# 37           0.247477           0.228216         0.231350        0.012093
# 38           0.243456           0.206166         0.228357        0.016028
# 39           0.243361           0.219172         0.228770        0.010487
# 40           0.232376           0.210693         0.220007        0.009112
# 41           0.205358           0.206147         0.210632        0.006908
# 42           0.219261           0.201829         0.217364        0.011984
# 43           0.216731           0.206147         0.217843        0.010035
# 44           0.214199           0.205329         0.216832        0.010631
# 45           0.187958           0.186972         0.180039        0.010509
# 46           0.224229           0.250903         0.236907        0.010929
# 47           0.237919           0.258538         0.242165        0.012017
# 48           0.256837           0.244643         0.247490        0.006776
# 49           0.241650           0.257142         0.240522        0.014054
# 50           0.225376           0.242690         0.231877        0.007698
# 51           0.221468           0.237998         0.229925        0.006754
# 52           0.228040           0.243936         0.234894        0.006671
# 53           0.207766           0.224290         0.223292        0.012290
# 54           0.187958           0.186972         0.180039        0.010509
# 55           0.234939           0.244990         0.233211        0.010395
# 56           0.242799           0.243344         0.242698        0.000574
# 57           0.241950           0.236751         0.236322        0.004780
# 58           0.244849           0.220388         0.232748        0.009988
# 59           0.229800           0.223275         0.228120        0.003479
# 60           0.220457           0.223512         0.222786        0.001686
# 61           0.210643           0.219566         0.219922        0.007725
# 62           0.210643           0.212755         0.217990        0.008939
# 63           0.187958           0.186972         0.180039        0.010509
# 64           0.256402           0.256561         0.240989        0.021909
# 65           0.249255           0.229456         0.233599        0.011473
# 66           0.225980           0.231128         0.222514        0.008797
# 67           0.230188           0.221216         0.220828        0.007806
# 68           0.230628           0.231533         0.222685        0.011879
# 69           0.236113           0.226976         0.223571        0.011877
# 70           0.229208           0.237028         0.220170        0.018588
# 71           0.215258           0.213174         0.211474        0.003971
# 72           0.187958           0.186972         0.180039        0.010509
# 73           0.249990           0.247563         0.237348        0.016193
# 74           0.255933           0.244283         0.240311        0.014649
# 75           0.247350           0.240851         0.237100        0.010249
# 76           0.221509           0.221658         0.228142        0.009275
# 77           0.222537           0.229628         0.232883        0.010044
# 78           0.211271           0.223632         0.225771        0.012802
# 79           0.229300           0.212563         0.231114        0.015938
# 80           0.212730           0.214203         0.225793        0.017443
#
#     rank_test_kappa
# 0                81
# 1                37
# 2                 7
# 3                 6
# 4                 4
# 5                 1
# 6                 5
# 7                 2
# 8                 3
# 9                73
# 10               15
# 11                9
# 12                8
# 13               10
# 14               14
# 15               11
# 16               12
# 17               16
# 18               80
# 19               22
# 20               20
# 21               13
# 22               17
# 23               23
# 24               34
# 25               41
# 26               55
# 27               79
# 28               31
# 29               21
# 30               19
# 31               24
# 32               32
# 33               33
# 34               35
# 35               27
# 36               74
# 37               48
# 38               52
# 39               51
# 40               65
# 41               72
# 42               69
# 43               68
# 44               70
# 45               75
# 46               39
# 47               26
# 48               18
# 49               29
# 50               47
# 51               50
# 52               42
# 53               59
# 54               75
# 55               44
# 56               25
# 57               40
# 58               46
# 59               54
# 60               60
# 61               66
# 62               67
# 63               75
# 64               28
# 65               43
# 66               62
# 67               63
# 68               61
# 69               58
# 70               64
# 71               71
# 72               75
# 73               36
# 74               30
# 75               38
# 76               53
# 77               45
# 78               57
# 79               49
# 80               56

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

pipe = Pipeline([
    ("model", HistGradientBoostingRegressor(max_iter=80, max_depth=3))
])

model = GridSearchCV(estimator=pipe,
                 param_grid={
                   'model__max_iter': [10,  30, 50, 70, 90, 110, 130, 150, 200], 
                   'model__max_depth': [1,  3, 5, 7, 9, 11, 13, 15, 20]  
                 },
                 scoring={'kappa': make_scorer(quadratic_weighted_kappa)},
                 refit='kappa',    
                 cv=3)

fit_params= {'model__sample_weight':train_weights}
model.fit(train_features.loc[:,train_features.columns!='id'], train_labels_pciat, **fit_params);


pred= model.predict(train_features.loc[:,train_features.columns!='id'])
plt.scatter(pred, train_labels_pciat)

# %%
pred_test= model.predict(test_features.loc[:,test_features.columns!='id'])
plt.scatter(pred_test, test_labels_pciat)

# %%
def get_sii_from_pciat (pred):
    condlist=[pred<=30, (pred>30)&(pred<50),(pred>=50)&(pred<80),(pred>=80) ]
    choicelist= [0,1,2,3]
    return (np.select(condlist,choicelist))

# %%
pred_train_sii = get_sii_from_pciat(pred)
pred_test_sii = get_sii_from_pciat(pred_test)

# %%
print(quadratic_weighted_kappa(train_labels_sii, pred_train_sii))
print (quadratic_weighted_kappa(test_labels_sii, pred_test_sii))
# Out:
# 0.5512108046209289
# 0.3647610752603032

# %% [markdown]
# Test Kappa - 0.3647610752603032 - for model trained on pciat with weights 5 \
# Test Kappa - 0.25945825437520875 - for model trained on sii with weights 5   with kappa socring for cv \
# Test Kappa - 0.3617637836515435 - for model trained on pciat with weights 2   with kappa socring for cv 3 fold \
# Test Kappa - 0.21012862387550768 - for model trained on sii with weights 2 \
# Test Kappa - 0.3617637836515435 - for model trained on pciat with weights 2 - without kapp scoring \
# Test Kappa - 0.3573678058172316 - for model trained on pciat with weights 2 - with kappa socring for cv 3 fold \

# %%
import eli5
from eli5.sklearn import PermutationImportance

# Calculate the feature importance
importances = PermutationImportance(model).fit(train_features.loc[:,train_features.columns!='id'], train_labels_pciat)

# Print the feature importance
eli5.show_weights(importances)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0943
#
#                     &plusmn; 0.0037
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x49
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0915
#
#                     &plusmn; 0.0122
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x45
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0880
#
#                     &plusmn; 0.0158
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0505
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x47
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0377
#
#                     &plusmn; 0.0028
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0318
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x13
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0220
#
#                     &plusmn; 0.0047
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0126
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x59
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0125
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x23
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0101
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x44
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0090
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x31
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0087
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x9
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0085
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x50
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0081
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x63
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x21
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0054
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x

# %%
test_features['prediction_pciat']=pred_test 
test_features['train_test']='test'

train_features['prediction_pciat']=pred 
train_features['train_test']='train'

total_prediction_df = pd.concat([train_features,test_features])
print (total_prediction_df.train_test.value_counts())
print (total_prediction_df.info())
#pred_test.shape
# Out:
# train    2173
# test      563
# Name: train_test, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2736 entries, 3 to 3955
# Data columns (total 67 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      2736 non-null   object
#  1   Basic_Demos-Age                         2736 non-null   int64
#  2   Basic_Demos-Sex                         2736 non-null   int64
#  3   CGAS-CGAS_Score                         2342 non-null   float64
#  4   Physical-BMI                            2527 non-null   float64
#  5   Physical-Height                         2530 non-null   float64
#  6   Physical-Weight                         2572 non-null   float64
#  7   Physical-Waist_Circumference            483 non-null    float64
#  8   Physical-Diastolic_BP                   2478 non-null   float64
#  9   Physical-HeartRate                      2486 non-null   float64
#  10  Physical-Systolic_BP                    2478 non-null   float64
#  11  Fitness_Endurance-Max_Stage             731 non-null    float64
#  12  Fitness_Endurance-Time_Mins             728 non-null    float64
#  13  Fitness_Endurance-Time_Sec              728 non-null    float64
#  14  FGC-FGC_CU                              1919 non-null   float64
#  15  FGC-FGC_CU_Zone                         1884 non-null   float64
#  16  FGC-FGC_GSND                            872 non-null    float64
#  17  FGC-FGC_GSND_Zone                       864 non-null    float64
#  18  FGC-FGC_GSD                             871 non-null    float64
#  19  FGC-FGC_GSD_Zone                        864 non-null    float64
#  20  FGC-FGC_PU                              1909 non-null   float64
#  21  FGC-FGC_PU_Zone                         1875 non-null   float64
#  22  FGC-FGC_SRL                             1911 non-null   float64
#  23  FGC-FGC_SRL_Zone                        1877 non-null   float64
#  24  FGC-FGC_SRR                             1913 non-null   float64
#  25  FGC-FGC_SRR_Zone                        1879 non-null   float64
#  26  FGC-FGC_TL                              1919 non-null   float64
#  27  FGC-FGC_TL_Zone                         1885 non-null   float64
#  28  BIA-BIA_Activity_Level_num              1813 non-null   float64
#  29  BIA-BIA_BMC                             1811 non-null   float64
#  30  BIA-BIA_BMI                             1813 non-null   float64
#  31  BIA-BIA_BMR                             1811 non-null   float64
#  32  BIA-BIA_DEE                             1811 non-null   float64
#  33  BIA-BIA_ECW                             1812 non-null   float64
#  34  BIA-BIA_FFM                             1811 non-null   float64
#  35  BIA-BIA_FFMI                            1813 non-null   float64
#  36  BIA-BIA_FMI                             1813 non-null   float64
#  37  BIA-BIA_Fat                             1782 non-null   float64
#  38  BIA-BIA_Frame_num                       1813 non-null   float64
#  39  BIA-BIA_ICW                             1811 non-null   float64
#  40  BIA-BIA_LDM                             1811 non-null   float64
#  41  BIA-BIA_LST                             1811 non-null   float64
#  42  BIA-BIA_SMM                             1811 non-null   float64
#  43  BIA-BIA_TBW                             1811 non-null   float64
#  44  PAQ_A-PAQ_A_Total                       363 non-null    float64
#  45  PAQ_C-PAQ_C_Total                       1440 non-null   float64
#  46  SDS-SDS_Total_Raw                       2527 non-null   float64
#  47  SDS-SDS_Total_T                         2525 non-null   float64
#  48  PreInt_EduHx-computerinternet_hoursday  2654 non-null   float64
#  49  Physical_BMI_Age                        2527 non-null   float64
#  50  Internet_Hours_Age                      2654 non-null   float64
#  51  Physical_BMI_Internet_Hours             2466 non-null   float64
#  52  BIA2_BFP_BMI                            1813 non-null   float64
#  53  BIA2_FFMI_BFP                           1813 non-null   float64
#  54  BIA2_FMI_BFP                            1813 non-null   float64
#  55  BIA2_LST_TBW                            1813 non-null   float64
#  56  BIA2_BFP_BMR                            1813 non-null   float64
#  57  BIA2_BFP_DEE                            1813 non-null   float64
#  58  BIA2_BMR_Weight                         1807 non-null   float64
#  59  BIA2_DEE_Weight                         1807 non-null   float64
#  60  BIA2_SMM_Height                         1807 non-null   float64
#  61  BIA2_Muscle_to_Fat                      1598 non-null   float64
#  62  BIA2_Hydration_Status                   1807 non-null   float64
#  63  BIA2_ICW_TBW                            1813 non-null   float64
#  64  rand_num                                2736 non-null   float64
#  65  prediction_pciat                        2736 non-null   float64
#  66  train_test                              2736 non-null   object
# dtypes: float64(63), int64(2), object(2)
# memory usage: 1.4+ MB
# None

# %%
total_prediction_df.to_csv('prediction_v1.csv')
