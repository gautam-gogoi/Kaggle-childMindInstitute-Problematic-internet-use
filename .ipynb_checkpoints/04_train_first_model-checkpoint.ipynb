# %% [markdown]
# ***Create first Simple model***\
# Author- Gautam Gogoi\
# Date - 17th Nov \
# Objective- Create first tree based model and understand results

# %%
import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score

# %%
# The following 3 functions have been taken from Ben Hamner's github repository
# https://github.com/benhamner/Metrics
def Cmatrix(rater_a, rater_b, min_rating=None, max_rating=None):
    """
    Returns the confusion matrix between rater's ratings
    """
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(rater_a + rater_b)
    if max_rating is None:
        max_rating = max(rater_a + rater_b)
    num_ratings = int(max_rating - min_rating + 1)
    conf_mat = [[0 for i in range(num_ratings)]
                for j in range(num_ratings)]
    for a, b in zip(rater_a, rater_b):
        conf_mat[a - min_rating][b - min_rating] += 1
    return conf_mat


def histogram(ratings, min_rating=None, max_rating=None):
    """
    Returns the counts of each type of rating that a rater made
    """
    if min_rating is None:
        min_rating = min(ratings)
    if max_rating is None:
        max_rating = max(ratings)
    num_ratings = int(max_rating - min_rating + 1)
    hist_ratings = [0 for x in range(num_ratings)]
    for r in ratings:
        hist_ratings[r - min_rating] += 1
    return hist_ratings


def quadratic_weighted_kappa(y, y_pred):
    """
    Calculates the quadratic weighted kappa
    axquadratic_weighted_kappa calculates the quadratic weighted kappa
    value, which is a measure of inter-rater agreement between two raters
    that provide discrete numeric ratings.  Potential values range from -1
    (representing complete disagreement) to 1 (representing complete
    agreement).  A kappa value of 0 is expected if all agreement is due to
    chance.
    quadratic_weighted_kappa(rater_a, rater_b), where rater_a and rater_b
    each correspond to a list of integer ratings.  These lists must have the
    same length.
    The ratings should be integers, and it is assumed that they contain
    the complete range of possible ratings.
    quadratic_weighted_kappa(X, min_rating, max_rating), where min_rating
    is the minimum possible rating, and max_rating is the maximum possible
    rating
    """
    rater_a = y
    rater_b = y_pred
    min_rating=None
    max_rating=None
    rater_a = np.array(rater_a, dtype=int)
    rater_b = np.array(rater_b, dtype=int)
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(min(rater_a), min(rater_b))
    if max_rating is None:
        max_rating = max(max(rater_a), max(rater_b))
    conf_mat = Cmatrix(rater_a, rater_b,
                                min_rating, max_rating)
    num_ratings = len(conf_mat)
    num_scored_items = float(len(rater_a))

    hist_rater_a = histogram(rater_a, min_rating, max_rating)
    hist_rater_b = histogram(rater_b, min_rating, max_rating)

    numerator = 0.0
    denominator = 0.0

    for i in range(num_ratings):
        for j in range(num_ratings):
            expected_count = (hist_rater_a[i] * hist_rater_b[j]
                              / num_scored_items)
            d = pow(i - j, 2.0) / pow(num_ratings - 1, 2.0)
            numerator += d * conf_mat[i][j] / num_scored_items
            denominator += d * expected_count / num_scored_items

    return (1.0 - numerator / denominator)

# %%
df = pd.read_pickle('df_featureEngg_v1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 99 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3960 non-null   object
#  1   Basic_Demos-Enroll_Season               3960 non-null   object
#  2   Basic_Demos-Age                         3960 non-null   int64
#  3   Basic_Demos-Sex                         3960 non-null   int64
#  4   CGAS-Season                             2555 non-null   object
#  5   CGAS-CGAS_Score                         2420 non-null   float64
#  6   Physical-Season                         3310 non-null   object
#  7   Physical-BMI                            3022 non-null   float64
#  8   Physical-Height                         3027 non-null   float64
#  9   Physical-Weight                         3076 non-null   float64
#  10  Physical-Waist_Circumference            898 non-null    float64
#  11  Physical-Diastolic_BP                   2954 non-null   float64
#  12  Physical-HeartRate                      2967 non-null   float64
#  13  Physical-Systolic_BP                    2954 non-null   float64
#  14  Fitness_Endurance-Season                1308 non-null   object
#  15  Fitness_Endurance-Max_Stage             743 non-null    float64
#  16  Fitness_Endurance-Time_Mins             740 non-null    float64
#  17  Fitness_Endurance-Time_Sec              740 non-null    float64
#  18  FGC-Season                              3346 non-null   object
#  19  FGC-FGC_CU                              2322 non-null   float64
#  20  FGC-FGC_CU_Zone                         2282 non-null   float64
#  21  FGC-FGC_GSND                            1074 non-null   float64
#  22  FGC-FGC_GSND_Zone                       1062 non-null   float64
#  23  FGC-FGC_GSD                             1074 non-null   float64
#  24  FGC-FGC_GSD_Zone                        1063 non-null   float64
#  25  FGC-FGC_PU                              2310 non-null   float64
#  26  FGC-FGC_PU_Zone                         2271 non-null   float64
#  27  FGC-FGC_SRL                             2305 non-null   float64
#  28  FGC-FGC_SRL_Zone                        2267 non-null   float64
#  29  FGC-FGC_SRR                             2307 non-null   float64
#  30  FGC-FGC_SRR_Zone                        2269 non-null   float64
#  31  FGC-FGC_TL                              2324 non-null   float64
#  32  FGC-FGC_TL_Zone                         2285 non-null   float64
#  33  BIA-Season                              2145 non-null   object
#  34  BIA-BIA_Activity_Level_num              1991 non-null   float64
#  35  BIA-BIA_BMC                             1989 non-null   float64
#  36  BIA-BIA_BMI                             1991 non-null   float64
#  37  BIA-BIA_BMR                             1989 non-null   float64
#  38  BIA-BIA_DEE                             1989 non-null   float64
#  39  BIA-BIA_ECW                             1990 non-null   float64
#  40  BIA-BIA_FFM                             1989 non-null   float64
#  41  BIA-BIA_FFMI                            1991 non-null   float64
#  42  BIA-BIA_FMI                             1991 non-null   float64
#  43  BIA-BIA_Fat                             1956 non-null   float64
#  44  BIA-BIA_Frame_num                       1991 non-null   float64
#  45  BIA-BIA_ICW                             1989 non-null   float64
#  46  BIA-BIA_LDM                             1989 non-null   float64
#  47  BIA-BIA_LST                             1989 non-null   float64
#  48  BIA-BIA_SMM                             1989 non-null   float64
#  49  BIA-BIA_TBW                             1989 non-null   float64
#  50  PAQ_A-Season                            475 non-null    object
#  51  PAQ_A-PAQ_A_Total                       475 non-null    float64
#  52  PAQ_C-Season                            1721 non-null   object
#  53  PAQ_C-PAQ_C_Total                       1721 non-null   float64
#  54  PCIAT-Season                            2736 non-null   object
#  55  PCIAT-PCIAT_01                          2733 non-null   float64
#  56  PCIAT-PCIAT_02                          2734 non-null   float64
#  57  PCIAT-PCIAT_03                          2731 non-null   float64
#  58  PCIAT-PCIAT_04                          2731 non-null   float64
#  59  PCIAT-PCIAT_05                          2729 non-null   float64
#  60  PCIAT-PCIAT_06                          2732 non-null   float64
#  61  PCIAT-PCIAT_07                          2729 non-null   float64
#  62  PCIAT-PCIAT_08                          2730 non-null   float64
#  63  PCIAT-PCIAT_09                          2730 non-null   float64
#  64  PCIAT-PCIAT_10                          2733 non-null   float64
#  65  PCIAT-PCIAT_11                          2734 non-null   float64
#  66  PCIAT-PCIAT_12                          2731 non-null   float64
#  67  PCIAT-PCIAT_13                          2729 non-null   float64
#  68  PCIAT-PCIAT_14                          2732 non-null   float64
#  69  PCIAT-PCIAT_15                          2730 non-null   float64
#  70  PCIAT-PCIAT_16                          2728 non-null   float64
#  71  PCIAT-PCIAT_17                          2725 non-null   float64
#  72  PCIAT-PCIAT_18                          2728 non-null   float64
#  73  PCIAT-PCIAT_19                          2730 non-null   float64
#  74  PCIAT-PCIAT_20                          2733 non-null   float64
#  75  PCIAT-PCIAT_Total                       2736 non-null   float64
#  76  SDS-Season                              2618 non-null   object
#  77  SDS-SDS_Total_Raw                       2609 non-null   float64
#  78  SDS-SDS_Total_T                         2606 non-null   float64
#  79  PreInt_EduHx-Season                     3540 non-null   object
#  80  PreInt_EduHx-computerinternet_hoursday  3301 non-null   float64
#  81  sii                                     3960 non-null   float64
#  82  Physical_BMI_Age                        3022 non-null   float64
#  83  Internet_Hours_Age                      3301 non-null   float64
#  84  Physical_BMI_Internet_Hours             2873 non-null   float64
#  85  BIA2_BFP_BMI                            1991 non-null   float64
#  86  BIA2_FFMI_BFP                           1991 non-null   float64
#  87  BIA2_FMI_BFP                            1991 non-null   float64
#  88  BIA2_LST_TBW                            1991 non-null   float64
#  89  BIA2_BFP_BMR                            1991 non-null   float64
#  90  BIA2_BFP_DEE                            1991 non-null   float64
#  91  BIA2_BMR_Weight                         1972 non-null   float64
#  92  BIA2_DEE_Weight                         1972 non-null   float64
#  93  BIA2_SMM_Height                         1971 non-null   float64
#  94  BIA2_Muscle_to_Fat                      1743 non-null   float64
#  95  BIA2_Hydration_Status                   1972 non-null   float64
#  96  BIA2_ICW_TBW                            1991 non-null   float64
#  97  rand_num                                3960 non-null   float64
#  98  test_train_flag                         3960 non-null   object
# dtypes: float64(84), int64(2), object(13)
# memory usage: 3.0+ MB

# %%
df['PCIAT-PCIAT_Total'].describe()
# Out:
# count    2736.000000
# mean       27.896199
# std        20.338853
# min         0.000000
# 25%        12.000000
# 50%        26.000000
# 75%        41.000000
# max        93.000000
# Name: PCIAT-PCIAT_Total, dtype: float64

# %%
df_sii = df[df['sii']>=0]
print (df_sii.sii.value_counts()) 
print (df_sii.test_train_flag.value_counts())
df_sii['weights'] = np.where(df_sii['sii']==3,5,1)
# Out:
# 0.0    1594
# 1.0     730
# 2.0     378
# 3.0      34
# Name: sii, dtype: int64
# Train    2173
# Test      563
# Name: test_train_flag, dtype: int64
# C:\Users\gogoig\AppData\Local\Temp\ipykernel_10100\2142392539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sii['weights'] = np.where(df_sii['sii']==3,5,1)

# %%
season_cols = [col for col in df_sii.columns if 'Season' in col]
df_sii = df_sii.drop(season_cols, axis=1) 
df_sii.columns
# Out:
# Index(['id', 'Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score',
#        'Physical-BMI', 'Physical-Height', 'Physical-Weight',
#        'Physical-Waist_Circumference', 'Physical-Diastolic_BP',
#        'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Max_Stage', 'Fitness_Endurance-Time_Mins',
#        'Fitness_Endurance-Time_Sec', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone',
#        'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone',
#        'FGC-FGC_PU', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone',
#        'FGC-FGC_SRR', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-PAQ_A_Total', 'PAQ_C-PAQ_C_Total',
#        'PCIAT-PCIAT_01', 'PCIAT-PCIAT_02', 'PCIAT-PCIAT_03', 'PCIAT-PCIAT_04',
#        'PCIAT-PCIAT_05', 'PCIAT-PCIAT_06', 'PCIAT-PCIAT_07', 'PCIAT-PCIAT_08',
#        'PCIAT-PCIAT_09', 'PCIAT-PCIAT_10', 'PCIAT-PCIAT_11', 'PCIAT-PCIAT_12',
#        'PCIAT-PCIAT_13', 'PCIAT-PCIAT_14', 'PCIAT-PCIAT_15', 'PCIAT-PCIAT_16',
#        'PCIAT-PCIAT_17', 'PCIAT-PCIAT_18', 'PCIAT-PCIAT_19', 'PCIAT-PCIAT_20',
#        'PCIAT-PCIAT_Total', 'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T',
#        'PreInt_EduHx-computerinternet_hoursday', 'sii', 'Physical_BMI_Age',
#        'Internet_Hours_Age', 'Physical_BMI_Internet_Hours', 'BIA2_BFP_BMI',
#        'BIA2_FFMI_BFP', 'BIA2_FMI_BFP', 'BIA2_LST_TBW', 'BIA2_BFP_BMR',
#        'BIA2_BFP_DEE', 'BIA2_BMR_Weight', 'BIA2_DEE_Weight', 'BIA2_SMM_Height',
#        'BIA2_Muscle_to_Fat', 'BIA2_Hydration_Status', 'BIA2_ICW_TBW',
#        'rand_num', 'test_train_flag', 'weights'],
#       dtype='object')

# %%
train_labels=df_sii[df_sii['test_train_flag']=='Train']['sii']
test_labels=df_sii[df_sii['test_train_flag']=='Test']['sii']

train_weights=df_sii[df_sii['test_train_flag']=='Train']['weights']
test_weights=df_sii[df_sii['test_train_flag']=='Test']['weights']

pciat_cols = [col for col in df_sii.columns if 'PCIAT-PCIAT' in col]
df_sii = df_sii.drop(pciat_cols, axis=1) 
df_sii = df_sii.drop(['sii', 'id'], axis=1)
df_sii.columns
# Out:
# Index(['Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Max_Stage', 'Fitness_Endurance-Time_Mins',
#        'Fitness_Endurance-Time_Sec', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone',
#        'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone',
#        'FGC-FGC_PU', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone',
#        'FGC-FGC_SRR', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-PAQ_A_Total', 'PAQ_C-PAQ_C_Total',
#        'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T',
#        'PreInt_EduHx-computerinternet_hoursday', 'Physical_BMI_Age',
#        'Internet_Hours_Age', 'Physical_BMI_Internet_Hours', 'BIA2_BFP_BMI',
#        'BIA2_FFMI_BFP', 'BIA2_FMI_BFP', 'BIA2_LST_TBW', 'BIA2_BFP_BMR',
#        'BIA2_BFP_DEE', 'BIA2_BMR_Weight', 'BIA2_DEE_Weight', 'BIA2_SMM_Height',
#        'BIA2_Muscle_to_Fat', 'BIA2_Hydration_Status', 'BIA2_ICW_TBW',
#        'rand_num', 'test_train_flag', 'weights'],
#       dtype='object')

# %%
print(test_labels.describe())
print(train_labels.describe())
# Out:
# count    563.000000
# mean       0.561279
# std        0.748231
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: sii, dtype: float64
# count    2173.000000
# mean        0.585366
# std         0.777034
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: sii, dtype: float64

# %%
train_features=df_sii[df_sii['test_train_flag']=='Train']
test_features=df_sii[df_sii['test_train_flag']=='Test']

train_features = train_features.drop(['test_train_flag'], axis=1)
test_features = test_features.drop(['test_train_flag'], axis=1)

# %%
print (test_features.info())
print (train_features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 0 to 3955
# Data columns (total 65 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Basic_Demos-Age                         563 non-null    int64
#  1   Basic_Demos-Sex                         563 non-null    int64
#  2   CGAS-CGAS_Score                         478 non-null    float64
#  3   Physical-BMI                            517 non-null    float64
#  4   Physical-Height                         518 non-null    float64
#  5   Physical-Weight                         525 non-null    float64
#  6   Physical-Waist_Circumference            106 non-null    float64
#  7   Physical-Diastolic_BP                   506 non-null    float64
#  8   Physical-HeartRate                      507 non-null    float64
#  9   Physical-Systolic_BP                    506 non-null    float64
#  10  Fitness_Endurance-Max_Stage             147 non-null    float64
#  11  Fitness_Endurance-Time_Mins             145 non-null    float64
#  12  Fitness_Endurance-Time_Sec              145 non-null    float64
#  13  FGC-FGC_CU                              384 non-null    float64
#  14  FGC-FGC_CU_Zone                         372 non-null    float64
#  15  FGC-FGC_GSND                            157 non-null    float64
#  16  FGC-FGC_GSND_Zone                       157 non-null    float64
#  17  FGC-FGC_GSD                             157 non-null    float64
#  18  FGC-FGC_GSD_Zone                        157 non-null    float64
#  19  FGC-FGC_PU                              381 non-null    float64
#  20  FGC-FGC_PU_Zone                         369 non-null    float64
#  21  FGC-FGC_SRL                             383 non-null    float64
#  22  FGC-FGC_SRL_Zone                        371 non-null    float64
#  23  FGC-FGC_SRR                             383 non-null    float64
#  24  FGC-FGC_SRR_Zone                        371 non-null    float64
#  25  FGC-FGC_TL                              385 non-null    float64
#  26  FGC-FGC_TL_Zone                         373 non-null    float64
#  27  BIA-BIA_Activity_Level_num              376 non-null    float64
#  28  BIA-BIA_BMC                             376 non-null    float64
#  29  BIA-BIA_BMI                             376 non-null    float64
#  30  BIA-BIA_BMR                             376 non-null    float64
#  31  BIA-BIA_DEE                             376 non-null    float64
#  32  BIA-BIA_ECW                             376 non-null    float64
#  33  BIA-BIA_FFM                             376 non-null    float64
#  34  BIA-BIA_FFMI                            376 non-null    float64
#  35  BIA-BIA_FMI                             376 non-null    float64
#  36  BIA-BIA_Fat                             369 non-null    float64
#  37  BIA-BIA_Frame_num                       376 non-null    float64
#  38  BIA-BIA_ICW                             376 non-null    float64
#  39  BIA-BIA_LDM                             376 non-null    float64
#  40  BIA-BIA_LST                             376 non-null    float64
#  41  BIA-BIA_SMM                             376 non-null    float64
#  42  BIA-BIA_TBW                             376 non-null    float64
#  43  PAQ_A-PAQ_A_Total                       69 non-null     float64
#  44  PAQ_C-PAQ_C_Total                       282 non-null    float64
#  45  SDS-SDS_Total_Raw                       507 non-null    float64
#  46  SDS-SDS_Total_T                         507 non-null    float64
#  47  PreInt_EduHx-computerinternet_hoursday  542 non-null    float64
#  48  Physical_BMI_Age                        517 non-null    float64
#  49  Internet_Hours_Age                      542 non-null    float64
#  50  Physical_BMI_Internet_Hours             504 non-null    float64
#  51  BIA2_BFP_BMI                            376 non-null    float64
#  52  BIA2_FFMI_BFP                           376 non-null    float64
#  53  BIA2_FMI_BFP                            376 non-null    float64
#  54  BIA2_LST_TBW                            376 non-null    float64
#  55  BIA2_BFP_BMR                            376 non-null    float64
#  56  BIA2_BFP_DEE                            376 non-null    float64
#  57  BIA2_BMR_Weight                         374 non-null    float64
#  58  BIA2_DEE_Weight                         374 non-null    float64
#  59  BIA2_SMM_Height                         374 non-null    float64
#  60  BIA2_Muscle_to_Fat                      327 non-null    float64
#  61  BIA2_Hydration_Status                   374 non-null    float64
#  62  BIA2_ICW_TBW                            376 non-null    float64
#  63  rand_num                                563 non-null    float64
#  64  weights                                 563 non-null    int32
# dtypes: float64(62), int32(1), int64(2)
# memory usage: 288.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2173 entries, 3 to 3958
# Data columns (total 65 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Basic_Demos-Age                         2173 non-null   int64
#  1   Basic_Demos-Sex                         2173 non-null   int64
#  2   CGAS-CGAS_Score                         1864 non-null   float64
#  3   Physical-BMI                            2010 non-null   float64
#  4   Physical-Height                         2012 non-null   float64
#  5   Physical-Weight                         2047 non-null   float64
#  6   Physical-Waist_Circumference            377 non-null    float64
#  7   Physical-Diastolic_BP                   1972 non-null   float64
#  8   Physical-HeartRate                      1979 non-null   float64
#  9   Physical-Systolic_BP                    1972 non-null   float64
#  10  Fitness_Endurance-Max_Stage             584 non-null    float64
#  11  Fitness_Endurance-Time_Mins             583 non-null    float64
#  12  Fitness_Endurance-Time_Sec              583 non-null    float64
#  13  FGC-FGC_CU                              1535 non-null   float64
#  14  FGC-FGC_CU_Zone                         1512 non-null   float64
#  15  FGC-FGC_GSND                            715 non-null    float64
#  16  FGC-FGC_GSND_Zone                       707 non-null    float64
#  17  FGC-FGC_GSD                             714 non-null    float64
#  18  FGC-FGC_GSD_Zone                        707 non-null    float64
#  19  FGC-FGC_PU                              1528 non-null   float64
#  20  FGC-FGC_PU_Zone                         1506 non-null   float64
#  21  FGC-FGC_SRL                             1528 non-null   float64
#  22  FGC-FGC_SRL_Zone                        1506 non-null   float64
#  23  FGC-FGC_SRR                             1530 non-null   float64
#  24  FGC-FGC_SRR_Zone                        1508 non-null   float64
#  25  FGC-FGC_TL                              1534 non-null   float64
#  26  FGC-FGC_TL_Zone                         1512 non-null   float64
#  27  BIA-BIA_Activity_Level_num              1437 non-null   float64
#  28  BIA-BIA_BMC                             1435 non-null   float64
#  29  BIA-BIA_BMI                             1437 non-null   float64
#  30  BIA-BIA_BMR                             1435 non-null   float64
#  31  BIA-BIA_DEE                             1435 non-null   float64
#  32  BIA-BIA_ECW                             1436 non-null   float64
#  33  BIA-BIA_FFM                             1435 non-null   float64
#  34  BIA-BIA_FFMI                            1437 non-null   float64
#  35  BIA-BIA_FMI                             1437 non-null   float64
#  36  BIA-BIA_Fat                             1413 non-null   float64
#  37  BIA-BIA_Frame_num                       1437 non-null   float64
#  38  BIA-BIA_ICW                             1435 non-null   float64
#  39  BIA-BIA_LDM                             1435 non-null   float64
#  40  BIA-BIA_LST                             1435 non-null   float64
#  41  BIA-BIA_SMM                             1435 non-null   float64
#  42  BIA-BIA_TBW                             1435 non-null   float64
#  43  PAQ_A-PAQ_A_Total                       294 non-null    float64
#  44  PAQ_C-PAQ_C_Total                       1158 non-null   float64
#  45  SDS-SDS_Total_Raw                       2020 non-null   float64
#  46  SDS-SDS_Total_T                         2018 non-null   float64
#  47  PreInt_EduHx-computerinternet_hoursday  2112 non-null   float64
#  48  Physical_BMI_Age                        2010 non-null   float64
#  49  Internet_Hours_Age                      2112 non-null   float64
#  50  Physical_BMI_Internet_Hours             1962 non-null   float64
#  51  BIA2_BFP_BMI                            1437 non-null   float64
#  52  BIA2_FFMI_BFP                           1437 non-null   float64
#  53  BIA2_FMI_BFP                            1437 non-null   float64
#  54  BIA2_LST_TBW                            1437 non-null   float64
#  55  BIA2_BFP_BMR                            1437 non-null   float64
#  56  BIA2_BFP_DEE                            1437 non-null   float64
#  57  BIA2_BMR_Weight                         1433 non-null   float64
#  58  BIA2_DEE_Weight                         1433 non-null   float64
#  59  BIA2_SMM_Height                         1433 non-null   float64
#  60  BIA2_Muscle_to_Fat                      1271 non-null   float64
#  61  BIA2_Hydration_Status                   1433 non-null   float64
#  62  BIA2_ICW_TBW                            1437 non-null   float64
#  63  rand_num                                2173 non-null   float64
#  64  weights                                 2173 non-null   int32
# dtypes: float64(62), int32(1), int64(2)
# memory usage: 1.1 MB
# None

# %%
model = HistGradientBoostingRegressor(max_iter=150, max_depth=2)
model.fit (train_features, train_labels,sample_weight = train_weights )

pred= model.predict(train_features)
plt.scatter(pred, train_labels)
quadratic_weighted_kappa(train_labels, pred)
# Out:
# 0.3892409847313154

# %%
pred_test= model.predict(test_features)
plt.scatter(pred_test, test_labels)
quadratic_weighted_kappa(test_labels, pred_test)
# Out:
# 0.24172600066978256

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

pipe = Pipeline([
    ("model", HistGradientBoostingRegressor(max_iter=80, max_depth=3))
])

model = GridSearchCV(estimator=pipe,
                 param_grid={
                   'model__max_iter': [10,  30, 50, 70, 90, 110, 130, 150, 200], 
                   'model__max_depth': [1,  3, 5, 7, 9, 11, 13, 15, 20]'  
                 },
                 cv=3)

fit_params= {'sample_weight':train_weights}
model.fit(train_features, train_labels, **fit_params);

#model = pipe.fit(train_features, train_labels)
pred= model.predict(train_features)
plt.scatter(pred, train_labels)

#reg = ensemble.GradientBoostingRegressor(**params)
#reg.fit(, )

#mse = mean_squared_error(y_test, reg.predict(X_test))
#print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# C:\Users\gogoig\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 243 fits failed out of a total of 243.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 243 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\gogoig\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\gogoig\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 389, in fit
#     fit_params_steps = self._check_fit_params(**fit_params)
#   File "C:\Users\gogoig\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 300, in _check_fit_params
#     raise ValueError(
# ValueError: Pipeline.fit does not accept the sample_weight parameter. You can pass parameters to specific steps of your pipeline using the stepname__parameter format, e.g. `Pipeline.fit(X, y, logisticregression__sample_weight=sample_weight)`.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\gogoig\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10100\2620183416.py in <module>
#      16
#      17 fit_params= {'sample_weight':train_weights}
# ---> 18 model.fit(train_features, train_labels, **fit_params);
#      19
#      20 #model = pipe.fit(train_features, train_labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     387             Pipeline with fitted steps.
#     388         """
# --> 389         fit_params_steps = self._check_fit_params(**fit_params)
#     390         Xt = self._fit(X, y, **fit_params_steps)
#     391         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _check_fit_params(self, **fit_params)
#     298         for pname, pval in fit_params.items():
#     299             if "__" not in pname:
# --> 300                 raise ValueError(
#     301                     "Pipeline.fit does not accept the {} parameter. "
#     302                     "You can pass parameters to specific steps of your "
#
# ValueError: Pipeline.fit does not accept the sample_weight parameter. You can pass parameters to specific steps of your pipeline using the stepname__parameter format, e.g. `Pipeline.fit(X, y, logisticregression__sample_weight=sample_weight)`.

# %%
pred_test= model.predict(test_features)
plt.scatter(pred_test, test_labels)

# %%
print(pd.DataFrame(pred).describe())
train_labels.describe()
# Out:
#                  0
# count  2173.000000
# mean     28.104464
# std      10.774166
# min       5.173259
# 25%      19.813813
# 50%      27.419337
# 75%      36.244533
# max      56.998056
# count    2173.000000
# mean       28.104464
# std        20.501418
# min         0.000000
# 25%        12.000000
# 50%        27.000000
# 75%        41.000000
# max        92.000000
# Name: PCIAT-PCIAT_Total, dtype: float64

# %%
quadratic_weighted_kappa(test_labels, pred_test)
# Out:
# 0.19827198205576602

# %%
pd.set_option('display.max_rows', 100)
pd.DataFrame(model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.031772      0.002077         0.002040        0.000057
# 1        0.043721      0.001700         0.002651        0.000464
# 2        0.056422      0.001354         0.003334        0.000472
# 3        0.069794      0.001795         0.004407        0.000637
# 4        0.079848      0.001693         0.004393        0.000215
# 5        0.092012      0.002277         0.005042        0.000340
# 6        0.110552      0.003877         0.005329        0.000525
# 7        0.118593      0.000818         0.005976        0.000493
# 8        0.153609      0.001552         0.008097        0.001139
# 9        0.047500      0.002152         0.002879        0.000456
# 10       0.085978      0.001323         0.002873        0.000228
# 11       0.124300      0.004123         0.003590        0.000738
# 12       0.150550      0.001529         0.004421        0.000243
# 13       0.188300      0.005058         0.004800        0.000441
# 14       0.229501      0.001483         0.005234        0.000263
# 15       0.264884      0.000912         0.006021        0.000698
# 16       0.298207      0.005997         0.006259        0.000479
# 17       0.379130      0.010280         0.007933        0.000477
# 18       0.093570      0.002626         0.002186        0.000262
# 19       0.197854      0.009476         0.003377        0.000532
# 20       0.267887      0.014826         0.004762        0.000462
# 21       0.352634      0.012038         0.004903        0.000222
# 22       0.411384      0.006945         0.005217        0.000611
# 23       0.546702      0.081151         0.006464        0.000972
# 24       0.631601      0.014382         0.006801        0.000491
# 25       0.629016      0.019185         0.008235        0.000369
# 26       0.769006      0.008427         0.008202        0.000232
# 27       0.127992      0.001470         0.002320        0.000452
# 28       0.310687      0.009570         0.004113        0.000032
# 29       0.394152      0.002130         0.003846        0.000637
# 30       0.513639      0.007887         0.005231        0.000535
# 31       0.606933      0.015645         0.005928        0.000188
# 32       0.733637      0.024013         0.006004        0.000644
# 33       0.831583      0.048205         0.006588        0.000323
# 34       0.949164      0.027917         0.007951        0.000170
# 35       1.182086      0.034303         0.009288        0.000870
# 36       0.143156      0.009929         0.002779        0.000179
# 37       0.326415      0.003720         0.003368        0.000522
# 38       0.453284      0.006860         0.004063        0.000052
# 39       0.576777      0.016901         0.005037        0.000051
# 40       0.717529      0.012399         0.005622        0.000409
# 41       0.833255      0.012856         0.007011        0.000393
# 42       0.989195      0.055174         0.007270        0.000236
# 43       1.091980      0.029834         0.007939        0.000266
# 44       1.531511      0.054023         0.010613        0.000271
# 45       0.132922      0.004783         0.002851        0.000211
# 46       0.340879      0.010503         0.004056        0.000082
# 47       0.484361      0.009454         0.003920        0.000250
# 48       0.633362      0.003266         0.005063        0.000047
# 49       0.793484      0.025361         0.005774        0.000286
# 50       0.925622      0.028414         0.006246        0.000301
# 51       1.102025      0.047113         0.007684        0.000484
# 52       1.359119      0.168494         0.008847        0.000138
# 53       1.896630      0.192035         0.012531        0.001332
# 54       0.169285      0.018900         0.004289        0.000569
# 55       0.422706      0.049970         0.004367        0.000905
# 56       0.576610      0.046563         0.004334        0.000471
# 57       0.714573      0.034481         0.004783        0.000683
# 58       0.875982      0.007138         0.007052        0.000895
# 59       1.476077      0.406393         0.008518        0.001908
# 60       1.195070      0.048979         0.007396        0.000823
# 61       1.339489      0.019216         0.008133        0.000525
# 62       1.798748      0.109266         0.010259        0.001051
# 63       0.133741      0.002841         0.002733        0.000490
# 64       0.351084      0.006111         0.002901        0.000141
# 65       0.524523      0.004435         0.004073        0.000054
# 66       0.697273      0.004933         0.004730        0.000462
# 67       0.900926      0.029895         0.005645        0.000354
# 68       1.051112      0.020317         0.006725        0.000267
# 69       1.348264      0.020661         0.008332        0.000557
# 70       1.466893      0.096752         0.008129        0.000417
# 71       1.866944      0.053929         0.010578        0.001472
# 72       0.133631      0.004092         0.003095        0.000023
# 73       0.343687      0.011100         0.003575        0.000427
# 74       0.745250      0.068727         0.004932        0.000568
# 75       0.762522      0.006383         0.005726        0.000585
# 76       0.953701      0.032048         0.005580        0.000373
# 77       1.151796      0.039533         0.007197        0.000091
# 78       1.341505      0.054360         0.008352        0.000403
# 79       1.584311      0.127453         0.009911        0.001891
# 80       2.178483      0.162721         0.011387        0.000720
#
#    param_model__max_depth param_model__max_iter  \
# 0                       1                    10
# 1                       1                    30
# 2                       1                    50
# 3                       1                    70
# 4                       1                    90
# 5                       1                   110
# 6                       1                   130
# 7                       1                   150
# 8                       1                   200
# 9                       3                    10
# 10                      3                    30
# 11                      3                    50
# 12                      3                    70
# 13                      3                    90
# 14                      3                   110
# 15                      3                   130
# 16                      3                   150
# 17                      3                   200
# 18                      5                    10
# 19                      5                    30
# 20                      5                    50
# 21                      5                    70
# 22                      5                    90
# 23                      5                   110
# 24                      5                   130
# 25                      5                   150
# 26                      5                   200
# 27                      7                    10
# 28                      7                    30
# 29                      7                    50
# 30                      7                    70
# 31                      7                    90
# 32                      7                   110
# 33                      7                   130
# 34                      7                   150
# 35                      7                   200
# 36                      9                    10
# 37                      9                    30
# 38                      9                    50
# 39                      9                    70
# 40                      9                    90
# 41                      9                   110
# 42                      9                   130
# 43                      9                   150
# 44                      9                   200
# 45                     11                    10
# 46                     11                    30
# 47                     11                    50
# 48                     11                    70
# 49                     11                    90
# 50                     11                   110
# 51                     11                   130
# 52                     11                   150
# 53                     11                   200
# 54                     13                    10
# 55                     13                    30
# 56                     13                    50
# 57                     13                    70
# 58                     13                    90
# 59                     13                   110
# 60                     13                   130
# 61                     13                   150
# 62                     13                   200
# 63                     15                    10
# 64                     15                    30
# 65                     15                    50
# 66                     15                    70
# 67                     15                    90
# 68                     15                   110
# 69                     15                   130
# 70                     15                   150
# 71                     15                   200
# 72                     20                    10
# 73                     20                    30
# 74                     20                    50
# 75                     20                    70
# 76                     20                    90
# 77                     20                   110
# 78                     20                   130
# 79                     20                   150
# 80                     20                   200
#
#                                               params  split0_test_score  \
# 0     {'model__max_depth': 1, 'model__max_iter': 10}           0.158698
# 1     {'model__max_depth': 1, 'model__max_iter': 30}           0.244476
# 2     {'model__max_depth': 1, 'model__max_iter': 50}           0.271385
# 3     {'model__max_depth': 1, 'model__max_iter': 70}           0.283440
# 4     {'model__max_depth': 1, 'model__max_iter': 90}           0.289341
# 5    {'model__max_depth': 1, 'model__max_iter': 110}           0.290940
# 6    {'model__max_depth': 1, 'model__max_iter': 130}           0.292861
# 7    {'model__max_depth': 1, 'model__max_iter': 150}           0.293738
# 8    {'model__max_depth': 1, 'model__max_iter': 200}           0.295669
# 9     {'model__max_depth': 3, 'model__max_iter': 10}           0.231371
# 10    {'model__max_depth': 3, 'model__max_iter': 30}           0.295902
# 11    {'model__max_depth': 3, 'model__max_iter': 50}           0.289901
# 12    {'model__max_depth': 3, 'model__max_iter': 70}           0.289195
# 13    {'model__max_depth': 3, 'model__max_iter': 90}           0.281811
# 14   {'model__max_depth': 3, 'model__max_iter': 110}           0.278049
# 15   {'model__max_depth': 3, 'model__max_iter': 130}           0.273256
# 16   {'model__max_depth': 3, 'model__max_iter': 150}           0.268308
# 17   {'model__max_depth': 3, 'model__max_iter': 200}           0.256948
# 18    {'model__max_depth': 5, 'model__max_iter': 10}           0.260953
# 19    {'model__max_depth': 5, 'model__max_iter': 30}           0.298419
# 20    {'model__max_depth': 5, 'model__max_iter': 50}           0.289572
# 21    {'model__max_depth': 5, 'model__max_iter': 70}           0.282997
# 22    {'model__max_depth': 5, 'model__max_iter': 90}           0.272182
# 23   {'model__max_depth': 5, 'model__max_iter': 110}           0.266859
# 24   {'model__max_depth': 5, 'model__max_iter': 130}           0.262435
# 25   {'model__max_depth': 5, 'model__max_iter': 150}           0.254653
# 26   {'model__max_depth': 5, 'model__max_iter': 200}           0.240117
# 27    {'model__max_depth': 7, 'model__max_iter': 10}           0.267870
# 28    {'model__max_depth': 7, 'model__max_iter': 30}           0.306178
# 29    {'model__max_depth': 7, 'model__max_iter': 50}           0.282529
# 30    {'model__max_depth': 7, 'model__max_iter': 70}           0.279935
# 31    {'model__max_depth': 7, 'model__max_iter': 90}           0.271763
# 32   {'model__max_depth': 7, 'model__max_iter': 110}           0.265931
# 33   {'model__max_depth': 7, 'model__max_iter': 130}           0.259591
# 34   {'model__max_depth': 7, 'model__max_iter': 150}           0.249836
# 35   {'model__max_depth': 7, 'model__max_iter': 200}           0.238931
# 36    {'model__max_depth': 9, 'model__max_iter': 10}           0.271045
# 37    {'model__max_depth': 9, 'model__max_iter': 30}           0.289648
# 38    {'model__max_depth': 9, 'model__max_iter': 50}           0.277312
# 39    {'model__max_depth': 9, 'model__max_iter': 70}           0.269377
# 40    {'model__max_depth': 9, 'model__max_iter': 90}           0.262363
# 41   {'model__max_depth': 9, 'model__max_iter': 110}           0.253640
# 42   {'model__max_depth': 9, 'model__max_iter': 130}           0.248460
# 43   {'model__max_depth': 9, 'model__max_iter': 150}           0.245261
# 44   {'model__max_depth': 9, 'model__max_iter': 200}           0.230619
# 45   {'model__max_depth': 11, 'model__max_iter': 10}           0.270456
# 46   {'model__max_depth': 11, 'model__max_iter': 30}           0.292844
# 47   {'model__max_depth': 11, 'model__max_iter': 50}           0.277499
# 48   {'model__max_depth': 11, 'model__max_iter': 70}           0.267149
# 49   {'model__max_depth': 11, 'model__max_iter': 90}           0.252034
# 50  {'model__max_depth': 11, 'model__max_iter': 110}           0.247419
# 51  {'model__max_depth': 11, 'model__max_iter': 130}           0.241618
# 52  {'model__max_depth': 11, 'model__max_iter': 150}           0.233551
# 53  {'model__max_depth': 11, 'model__max_iter': 200}           0.221718
# 54   {'model__max_depth': 13, 'model__max_iter': 10}           0.268797
# 55   {'model__max_depth': 13, 'model__max_iter': 30}           0.284704
# 56   {'model__max_depth': 13, 'model__max_iter': 50}           0.264749
# 57   {'model__max_depth': 13, 'model__max_iter': 70}           0.254361
# 58   {'model__max_depth': 13, 'model__max_iter': 90}           0.246727
# 59  {'model__max_depth': 13, 'model__max_iter': 110}           0.244030
# 60  {'model__max_depth': 13, 'model__max_iter': 130}           0.237457
# 61  {'model__max_depth': 13, 'model__max_iter': 150}           0.236350
# 62  {'model__max_depth': 13, 'model__max_iter': 200}           0.229171
# 63   {'model__max_depth': 15, 'model__max_iter': 10}           0.268797
# 64   {'model__max_depth': 15, 'model__max_iter': 30}           0.291414
# 65   {'model__max_depth': 15, 'model__max_iter': 50}           0.278998
# 66   {'model__max_depth': 15, 'model__max_iter': 70}           0.268566
# 67   {'model__max_depth': 15, 'model__max_iter': 90}           0.262212
# 68  {'model__max_depth': 15, 'model__max_iter': 110}           0.252493
# 69  {'model__max_depth': 15, 'model__max_iter': 130}           0.245032
# 70  {'model__max_depth': 15, 'model__max_iter': 150}           0.239721
# 71  {'model__max_depth': 15, 'model__max_iter': 200}           0.227644
# 72   {'model__max_depth': 20, 'model__max_iter': 10}           0.268797
# 73   {'model__max_depth': 20, 'model__max_iter': 30}           0.291512
# 74   {'model__max_depth': 20, 'model__max_iter': 50}           0.274571
# 75   {'model__max_depth': 20, 'model__max_iter': 70}           0.258171
# 76   {'model__max_depth': 20, 'model__max_iter': 90}           0.247492
# 77  {'model__max_depth': 20, 'model__max_iter': 110}           0.239509
# 78  {'model__max_depth': 20, 'model__max_iter': 130}           0.233785
# 79  {'model__max_depth': 20, 'model__max_iter': 150}           0.229459
# 80  {'model__max_depth': 20, 'model__max_iter': 200}           0.216091
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.171534           0.158942         0.163058        0.005994
# 1            0.262254           0.239755         0.248828        0.009687
# 2            0.290929           0.263749         0.275354        0.011446
# 3            0.307380           0.272953         0.287924        0.014408
# 4            0.314037           0.277439         0.293605        0.015242
# 5            0.318179           0.278239         0.295786        0.016662
# 6            0.319470           0.277721         0.296684        0.017257
# 7            0.320152           0.277086         0.296992        0.017732
# 8            0.319929           0.272724         0.296107        0.019274
# 9            0.249983           0.228092         0.236482        0.009640
# 10           0.314201           0.278775         0.296293        0.014465
# 11           0.309030           0.283933         0.294288        0.010705
# 12           0.305022           0.272221         0.288813        0.013394
# 13           0.297707           0.263393         0.280970        0.014022
# 14           0.292767           0.255965         0.275593        0.015124
# 15           0.289800           0.253921         0.272326        0.014662
# 16           0.285694           0.253079         0.269027        0.013325
# 17           0.272715           0.237756         0.255806        0.014295
# 18           0.246658           0.230133         0.245914        0.012593
# 19           0.282000           0.253327         0.277915        0.018634
# 20           0.278866           0.246430         0.271623        0.018342
# 21           0.272621           0.237830         0.264483        0.019316
# 22           0.266680           0.232099         0.256987        0.017741
# 23           0.260382           0.231181         0.252807        0.015519
# 24           0.249614           0.223370         0.245140        0.016259
# 25           0.243690           0.223685         0.240676        0.012821
# 26           0.234371           0.208386         0.227625        0.013805
# 27           0.255919           0.232398         0.252062        0.014736
# 28           0.291689           0.245954         0.281274        0.025666
# 29           0.282318           0.232848         0.265898        0.023370
# 30           0.270886           0.224955         0.258592        0.024070
# 31           0.258115           0.214888         0.248255        0.024243
# 32           0.244023           0.207755         0.239236        0.023990
# 33           0.237586           0.203135         0.233437        0.023234
# 34           0.226089           0.193256         0.223061        0.023198
# 35           0.207399           0.179829         0.208720        0.024147
# 36           0.253071           0.223368         0.249161        0.019659
# 37           0.285588           0.235027         0.270088        0.024847
# 38           0.276240           0.221218         0.258257        0.026194
# 39           0.265912           0.203662         0.246317        0.030195
# 40           0.255079           0.189534         0.235659        0.032750
# 41           0.246434           0.180714         0.226929        0.032811
# 42           0.238057           0.172103         0.219540        0.033811
# 43           0.232426           0.161276         0.212988        0.036939
# 44           0.215515           0.152746         0.199627        0.033718
# 45           0.252345           0.226289         0.249697        0.018128
# 46           0.293865           0.240892         0.275867        0.024734
# 47           0.278670           0.227166         0.261112        0.024008
# 48           0.265975           0.211330         0.248151        0.026041
# 49           0.259094           0.201445         0.237525        0.025674
# 50           0.249152           0.189642         0.228737        0.027654
# 51           0.243298           0.180868         0.221928        0.029042
# 52           0.232363           0.170612         0.212176        0.029394
# 53           0.214750           0.157749         0.198072        0.028654
# 54           0.252345           0.224837         0.248660        0.018135
# 55           0.294326           0.224177         0.267736        0.031050
# 56           0.281425           0.211350         0.252508        0.029889
# 57           0.266781           0.200832         0.240658        0.028614
# 58           0.255619           0.194643         0.232330        0.026895
# 59           0.245500           0.182568         0.224033        0.029326
# 60           0.238370           0.173192         0.216340        0.030512
# 61           0.231278           0.169492         0.212373        0.030392
# 62           0.216577           0.158780         0.201510        0.030649
# 63           0.252345           0.224837         0.248660        0.018135
# 64           0.295783           0.224177         0.270458        0.032774
# 65           0.285584           0.210657         0.258413        0.033875
# 66           0.270452           0.193010         0.244009        0.036070
# 67           0.255188           0.180598         0.232666        0.036929
# 68           0.247168           0.171853         0.223838        0.036823
# 69           0.239765           0.160874         0.215224        0.038491
# 70           0.234470           0.152843         0.209011        0.039775
# 71           0.218234           0.138088         0.194655        0.040183
# 72           0.252345           0.224837         0.248660        0.018135
# 73           0.295372           0.224177         0.270354        0.032690
# 74           0.287118           0.210932         0.257540        0.033353
# 75           0.267676           0.194712         0.240186        0.032389
# 76           0.253886           0.183416         0.228264        0.031820
# 77           0.248107           0.177696         0.221771        0.031363
# 78           0.239710           0.174834         0.216110        0.029287
# 79           0.231118           0.170339         0.210305        0.028269
# 80           0.217357           0.163019         0.198822        0.025322
#
#     rank_test_score
# 0                81
# 1                37
# 2                15
# 3                 9
# 4                 7
# 5                 5
# 6                 2
# 7                 1
# 8                 4
# 9                52
# 10                3
# 11                6
# 12                8
# 13               11
# 14               14
# 15               16
# 16               21
# 17               31
# 18               44
# 19               12
# 20               17
# 21               24
# 22               30
# 23               32
# 24               45
# 25               47
# 26               59
# 27               34
# 28               10
# 29               23
# 30               26
# 31               41
# 32               50
# 33               54
# 34               63
# 35               75
# 36               36
# 37               20
# 38               28
# 39               43
# 40               53
# 41               60
# 42               66
# 43               70
# 44               77
# 45               35
# 46               13
# 47               25
# 48               42
# 49               51
# 50               57
# 51               64
# 52               72
# 53               79
# 54               38
# 55               22
# 56               33
# 57               48
# 58               56
# 59               61
# 60               67
# 61               71
# 62               76
# 63               38
# 64               18
# 65               27
# 66               46
# 67               55
# 68               62
# 69               69
# 70               74
# 71               80
# 72               38
# 73               19
# 74               29
# 75               49
# 76               58
# 77               65
# 78               68
# 79               73
# 80               78

# %%
import eli5
from eli5.sklearn import PermutationImportance

# Calculate the feature importance
importances = PermutationImportance(model).fit(train_features, train_labels)

# Print the feature importance
eli5.show_weights(importances)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1827
#
#                     &plusmn; 0.0221
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1825
#
#                     &plusmn; 0.0178
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x45
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0998
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x47
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0787
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x49
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0494
#
#                     &plusmn; 0.0032
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x13
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0469
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0465
#
#                     &plusmn; 0.0037
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0395
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x44
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0378
#
#                     &plusmn; 0.0038
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x9
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0366
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x63
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0361
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0275
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x8
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0274
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0257
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x7
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0247
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x25
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0236
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x50
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0229
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x21
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0220
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x23

# %%
importances
# Out:
# PermutationImportance(estimator=HistGradientBoostingRegressor())
