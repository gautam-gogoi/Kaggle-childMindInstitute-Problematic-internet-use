# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\gogoig\\Kaggle\\child-mind-institute-problematic-internet-use\\train.csv')
print(df.head())
print(df.info())
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
# ...

# %%
df['PCIAT-PCIAT_01'].fillna(-999).value_counts()
# Out:
# -999.0    1227
#  2.0       599
#  0.0       543
#  4.0       482
#  3.0       418
#  5.0       352
#  1.0       339
# Name: PCIAT-PCIAT_01, dtype: int64

# %%
pd.set_option('display.max_rows', 500)
df[df['PCIAT-PCIAT_01'].isna()].describe().transpose()
# Out:
#                                          count         mean         std  \
# Basic_Demos-Age                         1227.0    10.868786    3.848039
# Basic_Demos-Sex                         1227.0     0.391198    0.488218
# CGAS-CGAS_Score                           81.0    74.061728  104.595572
# Physical-BMI                             497.0    20.366430    5.942239
# Physical-Height                          499.0    56.186693    7.858878
# Physical-Weight                          506.0    95.035870   49.867681
# Physical-Waist_Circumference             416.0    28.024279    5.851051
# Physical-Diastolic_BP                    478.0    69.081590   12.616901
# Physical-HeartRate                       483.0    80.455487   13.058263
# Physical-Systolic_BP                     478.0   116.238494   16.165860
# Fitness_Endurance-Max_Stage               13.0     4.230769    1.690850
# Fitness_Endurance-Time_Mins               13.0     5.846154    3.411895
# ...

# %%
import random 

df['rand_num']= 
np.floor(100*np.random.rand(100))
#df.sii.fillna(-1).value_counts()
#rows = random.sample(base_v5.index, 4000000)

#base_v5['train_flag'] = base_v5.index.isin(rows)
# Out:
# array([58., 14., 15., 34., 89.,  9., 56., 51., 69., 75., 33., 76., 32.,
#        69., 72.,  8., 92., 28., 76., 41., 64., 34., 90., 97., 48., 99.,
#         3., 85., 58., 16., 84., 51., 81., 69., 89., 96., 41., 87., 15.,
#        48., 24.,  9., 16., 58., 45.,  9.,  7., 29., 53., 95., 13., 21.,
#        38., 15., 56., 99., 59., 79., 21., 42., 18.,  9., 61., 16., 37.,
#        37., 89., 63., 17., 18., 75., 97., 11., 80., 18., 62., 94., 73.,
#        39., 22., 47., 97., 62., 10., 22.,  5., 97., 88., 90., 90., 64.,
#        63., 92., 15., 87.,  6.,  0., 43., 23., 96.])

# %%
df.to_pickle('df_featureEngg.pkl')
